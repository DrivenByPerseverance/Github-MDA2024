# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
itv_aed = pd.read_csv(
    '/Users/lye/Downloads/MDA/Github-MDA2024/1_Data/CLEANED/intervention_aed_related_distance.csv',
    low_memory=False)

itv_aed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105841 entries, 0 to 105840
# Data columns (total 58 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   mission_id                        105841 non-null  int64
#  1   service_name                      93471 non-null   object
#  2   postalcode_permanence             65151 non-null   float64
#  3   cityname_permanence               69218 non-null   object
#  4   streetname_permanence             69623 non-null   object
#  5   housenumber_permanence            2667 non-null    float64
#  6   latitude_permanence               97007 non-null   float64
#  7   longitude_permanence              97690 non-null   float64
#  8   permanence_short_name             105670 non-null  object
#  9   permanence_long_name              93486 non-null   object
#  10  vector_type                       104009 non-null  object
#  11  eventtype_firstcall               65569 non-null   object
#  12  eventlevel_firstcall              65446 non-null   object
#  13  eventtype_trip                    105841 non-null  object
#  14  eventlevel_trip                   105830 non-null  object
#  15  postalcode_intervention           0 non-null       float64
#  16  cityname_intervention             105831 non-null  object
#  17  lat_itv                           105841 non-null  float64
#  18  lon_itv                           105841 non-null  float64
#  19  t0                                105548 non-null  object
#  20  t1                                103974 non-null  object
#  21  t1confirmed                       63228 non-null   object
#  22  t2                                95663 non-null   object
#  23  t3                                90823 non-null   object
#  24  t4                                72427 non-null   object
#  25  t5                                62161 non-null   object
#  26  t6                                84697 non-null   object
#  27  t7                                67215 non-null   object
#  28  t9                                4 non-null       object
#  29  intervention_time_(t1reported)    89706 non-null   float64
#  30  waiting_time                      57572 non-null   float64
#  31  intervention_duration             50080 non-null   float64
#  32  departure_time_(t1reported)       94379 non-null   float64
#  33  unavailable_time                  3 non-null       float64
#  34  name_destination_hospital         62362 non-null   object
#  35  postalcode_destination_hospital   1 non-null       float64
#  36  cityname_destination_hospital     37629 non-null   object
#  37  streetname_destination_hospital   37588 non-null   object
#  38  housenumber_destination_hospital  0 non-null       float64
#  39  calculated_traveltime_destinatio  31827 non-null   float64
#  40  calculated_distance_destination   31827 non-null   float64
#  41  number_of_transported_persons     32193 non-null   float64
#  42  abandon_reason                    11538 non-null   object
#  43  t0_Hour                           105548 non-null  float64
#  44  t0_Day                            105548 non-null  float64
#  45  t0_Month                          105548 non-null  float64
#  46  t0_Year                           105548 non-null  float64
#  47  t0_DayName                        105548 non-null  object
#  48  t7_Hour                           67215 non-null   float64
#  49  t7_Day                            67215 non-null   float64
#  50  t7_Month                          67215 non-null   float64
#  51  t7_Year                           67215 non-null   float64
#  52  t7_DayName                        67215 non-null   object
#  53  province                          105841 non-null  object
#  54  intervention_time_(t1confirmed)   59473 non-null   float64
#  55  departure_time_(t1confirmed)      62215 non-null   float64
#  56  aed_distance                      105841 non-null  float64
#  57  hospital_distance                 105841 non-null  float64
# dtypes: float64(29), int64(1), object(28)
# memory usage: 46.8+ MB

# %%
## Datetime validation

itv_aed['t0'] = pd.to_datetime(itv_aed['t0'])
itv_aed['t3'] = pd.to_datetime(itv_aed['t3'])
itv_aed['t5'] = pd.to_datetime(itv_aed['t5'])
itv_aed['t7'] = pd.to_datetime(itv_aed['t7'])
itv_aed['t3-t0'] = (itv_aed['t3'] - itv_aed['t0']).dt.total_seconds() / 60
itv_aed['t5-t0'] = (itv_aed['t5'] - itv_aed['t0']).dt.total_seconds() / 60
itv_aed['total_time'] = (itv_aed['t7'] - itv_aed['t0']).dt.total_seconds() / 60

itv_aed.loc[(itv_aed['t3-t0'] <= 0) | (itv_aed['t3-t0'] > 6 * 60), 't3-t0'] = np.nan
itv_aed.loc[(itv_aed['t5-t0'] <= 0) | (itv_aed['t5-t0'] > 12 * 60) | (itv_aed['t5-t0'] <= itv_aed['t3-t0']), 't5-t0'] = np.nan
itv_aed.loc[(itv_aed['waiting_time'] <= 0) | (itv_aed['waiting_time'] > 6 * 60), 'waiting_time'] = np.nan
itv_aed['t3-t0'] = itv_aed.apply(
    lambda x: x['waiting_time']
    if pd.isna(x['t3-t0']) and pd.notna(x['waiting_time']) else x['t3-t0'],
    axis=1)

itv_aed.loc[(itv_aed['total_time']<=0) | (itv_aed['total_time'] <= itv_aed['t5-t0']), 'total_time'] = np.nan
itv_aed.drop(columns=['waiting_time'], inplace=True)
itv_aed.rename(columns={'t3-t0': 'waiting_time', 't5-t0': 'time_to_hospital'}, inplace=True) ## rename to waiting_time & time_to_hospital

itv_aed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105841 entries, 0 to 105840
# Data columns (total 60 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   mission_id                        105841 non-null  int64
#  1   service_name                      93471 non-null   object
#  2   postalcode_permanence             65151 non-null   float64
#  3   cityname_permanence               69218 non-null   object
#  4   streetname_permanence             69623 non-null   object
#  5   housenumber_permanence            2667 non-null    float64
#  6   latitude_permanence               97007 non-null   float64
#  7   longitude_permanence              97690 non-null   float64
#  8   permanence_short_name             105670 non-null  object
#  9   permanence_long_name              93486 non-null   object
#  10  vector_type                       104009 non-null  object
#  11  eventtype_firstcall               65569 non-null   object
#  12  eventlevel_firstcall              65446 non-null   object
#  13  eventtype_trip                    105841 non-null  object
#  14  eventlevel_trip                   105830 non-null  object
#  15  postalcode_intervention           0 non-null       float64
#  16  cityname_intervention             105831 non-null  object
#  17  lat_itv                           105841 non-null  float64
#  18  lon_itv                           105841 non-null  float64
#  19  t0                                105548 non-null  datetime64[ns]
#  20  t1                                103974 non-null  object
#  21  t1confirmed                       63228 non-null   object
#  22  t2                                95663 non-null   object
#  23  t3                                90823 non-null   datetime64[ns]
#  24  t4                                72427 non-null   object
#  25  t5                                62161 non-null   datetime64[ns]
#  26  t6                                84697 non-null   object
#  27  t7                                67215 non-null   datetime64[ns]
#  28  t9                                4 non-null       object
#  29  intervention_time_(t1reported)    89706 non-null   float64
#  30  intervention_duration             50080 non-null   float64
#  31  departure_time_(t1reported)       94379 non-null   float64
#  32  unavailable_time                  3 non-null       float64
#  33  name_destination_hospital         62362 non-null   object
#  34  postalcode_destination_hospital   1 non-null       float64
#  35  cityname_destination_hospital     37629 non-null   object
#  36  streetname_destination_hospital   37588 non-null   object
#  37  housenumber_destination_hospital  0 non-null       float64
#  38  calculated_traveltime_destinatio  31827 non-null   float64
#  39  calculated_distance_destination   31827 non-null   float64
#  40  number_of_transported_persons     32193 non-null   float64
#  41  abandon_reason                    11538 non-null   object
#  42  t0_Hour                           105548 non-null  float64
#  43  t0_Day                            105548 non-null  float64
#  44  t0_Month                          105548 non-null  float64
#  45  t0_Year                           105548 non-null  float64
#  46  t0_DayName                        105548 non-null  object
#  47  t7_Hour                           67215 non-null   float64
#  48  t7_Day                            67215 non-null   float64
#  49  t7_Month                          67215 non-null   float64
#  50  t7_Year                           67215 non-null   float64
#  51  t7_DayName                        67215 non-null   object
#  52  province                          105841 non-null  object
#  53  intervention_time_(t1confirmed)   59473 non-null   float64
#  54  departure_time_(t1confirmed)      62215 non-null   float64
#  55  aed_distance                      105841 non-null  float64
#  56  hospital_distance                 105841 non-null  float64
#  57  waiting_time                      83454 non-null   float64
#  58  time_to_hospital                  55692 non-null   float64
#  59  total_time                        62505 non-null   float64
# dtypes: datetime64[ns](4), float64(31), int64(1), object(24)
# memory usage: 48.5+ MB

# %%
## drop duplicates and missing values
itv_aed.drop_duplicates(subset=['mission_id'], inplace=True)
itv_aed.dropna(subset=[
    'waiting_time', 'total_time', 'time_to_hospital', 'aed_distance', 'hospital_distance',
    'province', 'vector_type', 'eventlevel_trip'
], inplace=True)

## validate vector_type
itv_aed['vector_type'] = itv_aed['vector_type'].apply(lambda x: "AMBULANCE" if any(
    i in x.lower() for i in ["ambulance", "amb"]) else 'MUG' if any(
    i in x.lower() for i in ['mug']) else 'PIT' if any(
    i in x.lower() for i in ['pit']) else x)

itv_aed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22651 entries, 5 to 105258
# Data columns (total 60 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   mission_id                        22651 non-null  int64
#  1   service_name                      22651 non-null  object
#  2   postalcode_permanence             21667 non-null  float64
#  3   cityname_permanence               22598 non-null  object
#  4   streetname_permanence             22647 non-null  object
#  5   housenumber_permanence            1027 non-null   float64
#  6   latitude_permanence               22629 non-null  float64
#  7   longitude_permanence              22545 non-null  float64
#  8   permanence_short_name             22651 non-null  object
#  9   permanence_long_name              22651 non-null  object
#  10  vector_type                       22651 non-null  object
#  11  eventtype_firstcall               21715 non-null  object
#  12  eventlevel_firstcall              21699 non-null  object
#  13  eventtype_trip                    22651 non-null  object
#  14  eventlevel_trip                   22651 non-null  object
#  15  postalcode_intervention           0 non-null      float64
#  16  cityname_intervention             22648 non-null  object
#  17  lat_itv                           22651 non-null  float64
#  18  lon_itv                           22651 non-null  float64
#  19  t0                                22651 non-null  datetime64[ns]
#  20  t1                                22650 non-null  object
#  21  t1confirmed                       17628 non-null  object
#  22  t2                                22381 non-null  object
#  23  t3                                22651 non-null  datetime64[ns]
#  24  t4                                22033 non-null  object
#  25  t5                                22651 non-null  datetime64[ns]
#  26  t6                                16526 non-null  object
#  27  t7                                22651 non-null  datetime64[ns]
#  28  t9                                0 non-null      object
#  29  intervention_time_(t1reported)    21720 non-null  float64
#  30  intervention_duration             15986 non-null  float64
#  31  departure_time_(t1reported)       21455 non-null  float64
#  32  unavailable_time                  0 non-null      float64
#  33  name_destination_hospital         20628 non-null  object
#  34  postalcode_destination_hospital   0 non-null      float64
#  35  cityname_destination_hospital     20624 non-null  object
#  36  streetname_destination_hospital   20612 non-null  object
#  37  housenumber_destination_hospital  0 non-null      float64
#  38  calculated_traveltime_destinatio  17395 non-null  float64
#  39  calculated_distance_destination   17395 non-null  float64
#  40  number_of_transported_persons     18749 non-null  float64
#  41  abandon_reason                    62 non-null     object
#  42  t0_Hour                           22651 non-null  float64
#  43  t0_Day                            22651 non-null  float64
#  44  t0_Month                          22651 non-null  float64
#  45  t0_Year                           22651 non-null  float64
#  46  t0_DayName                        22651 non-null  object
#  47  t7_Hour                           22651 non-null  float64
#  48  t7_Day                            22651 non-null  float64
#  49  t7_Month                          22651 non-null  float64
#  50  t7_Year                           22651 non-null  float64
#  51  t7_DayName                        22651 non-null  object
#  52  province                          22651 non-null  object
#  53  intervention_time_(t1confirmed)   17619 non-null  float64
#  54  departure_time_(t1confirmed)      17378 non-null  float64
#  55  aed_distance                      22651 non-null  float64
#  56  hospital_distance                 22651 non-null  float64
#  57  waiting_time                      22651 non-null  float64
#  58  time_to_hospital                  22651 non-null  float64
#  59  total_time                        22651 non-null  float64
# dtypes: datetime64[ns](4), float64(31), int64(1), object(24)
# memory usage: 10.5+ MB

# %%
## Delete 'provincie' in province column
itv_aed['province'] = itv_aed['province'].apply(lambda x: x.replace('Provincie ', ''))
itv_aed['province'].value_counts()
# Out:
# province
# Antwerpen                         5977
# Brussels Hoofdstedelijk Gewest    4413
# Henegouwen                        3623
# Luik                              2739
# Limburg                           2540
# Namen                             1252
# Waals-Brabant                     1026
# Luxemburg                          892
# Vlaams-Brabant                     174
# Oost-Vlaanderen                      8
# West-Vlaanderen                      7
# Name: count, dtype: int64

# %%
itv_aed.to_csv('/Users/lye/Downloads/MDA/Github-MDA2024/1_Data/CLEANED/clean_itv_aed_for_analysis.csv', index=False)

# %%
columns_to_keep = [
    'aed_distance', 'hospital_distance', 'waiting_time', 'time_to_hospital', 'total_time', 'province', 'vector_type', 'eventlevel_trip', 'eventtype_trip'
]

itv_reg = itv_aed[columns_to_keep].copy()
itv_reg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22651 entries, 5 to 105258
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   aed_distance       22651 non-null  float64
#  1   hospital_distance  22651 non-null  float64
#  2   waiting_time       22651 non-null  float64
#  3   time_to_hospital   22651 non-null  float64
#  4   total_time         22651 non-null  float64
#  5   province           22651 non-null  object
#  6   vector_type        22651 non-null  object
#  7   eventlevel_trip    22651 non-null  object
#  8   eventtype_trip     22651 non-null  object
# dtypes: float64(5), object(4)
# memory usage: 1.7+ MB

# %%
itv_reg = pd.get_dummies(itv_reg, columns=['province', 'vector_type', 'eventlevel_trip', 'eventtype_trip'], drop_first=True)
itv_reg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22651 entries, 5 to 105258
# Data columns (total 26 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   aed_distance                                                      22651 non-null  float64
#  1   hospital_distance                                                 22651 non-null  float64
#  2   waiting_time                                                      22651 non-null  float64
#  3   time_to_hospital                                                  22651 non-null  float64
#  4   total_time                                                        22651 non-null  float64
#  5   province_Brussels Hoofdstedelijk Gewest                           22651 non-null  bool
#  6   province_Henegouwen                                               22651 non-null  bool
#  7   province_Limburg                                                  22651 non-null  bool
#  8   province_Luik                                                     22651 non-null  bool
#  9   province_Luxemburg                                                22651 non-null  bool
#  10  province_Namen                                                    22651 non-null  bool
#  11  province_Oost-Vlaanderen                                          22651 non-null  bool
#  12  province_Vlaams-Brabant                                           22651 non-null  bool
#  13  province_Waals-Brabant                                            22651 non-null  bool
#  14  province_West-Vlaanderen                                          22651 non-null  bool
#  15  vector_type_MUG                                                   22651 non-null  bool
#  16  vector_type_PIT                                                   22651 non-null  bool
#  17  eventlevel_trip_N1                                                22651 non-null  bool
#  18  eventlevel_trip_N2                                                22651 non-null  bool
#  19  eventlevel_trip_N3                                                22651 non-null  bool
#  20  eventlevel_trip_N4                                                22651 non-null  bool
#  21  eventlevel_trip_N5                                                22651 non-null  bool
#  22  eventlevel_trip_N6                                                22651 non-null  bool
#  23  eventlevel_trip_N7A                                               22651 non-null  bool
#  24  eventtype_trip_P019 - Unconscious - syncope                       22651 non-null  bool
#  25  eventtype_trip_P039 - Cardiac problem (other than thoracic pain)  22651 non-null  bool
# dtypes: bool(21), float64(5)
# memory usage: 1.5 MB

# %%
itv_reg.columns
# Out:
# Index(['aed_distance', 'hospital_distance', 'waiting_time', 'time_to_hospital',
#        'total_time', 'province_Brussels Hoofdstedelijk Gewest',
#        'province_Henegouwen', 'province_Limburg', 'province_Luik',
#        'province_Luxemburg', 'province_Namen', 'province_Oost-Vlaanderen',
#        'province_Vlaams-Brabant', 'province_Waals-Brabant',
#        'province_West-Vlaanderen', 'vector_type_MUG', 'vector_type_PIT',
#        'eventlevel_trip_N1', 'eventlevel_trip_N2', 'eventlevel_trip_N3',
#        'eventlevel_trip_N4', 'eventlevel_trip_N5', 'eventlevel_trip_N6',
#        'eventlevel_trip_N7A', 'eventtype_trip_P019 - Unconscious - syncope',
#        'eventtype_trip_P039 - Cardiac problem (other than thoracic pain)'],
#       dtype='object')

# %%
## OLS regression on total_time

import statsmodels.api as sm

X_var = ['aed_distance', 'hospital_distance', 'province_Brussels Hoofdstedelijk Gewest',
       'province_Henegouwen', 'province_Limburg', 'province_Luik',
       'province_Luxemburg', 'province_Namen', 'province_Oost-Vlaanderen',
       'province_Vlaams-Brabant', 'province_Waals-Brabant',
       'province_West-Vlaanderen', 'vector_type_MUG', 'vector_type_PIT',
       'eventlevel_trip_N1', 'eventlevel_trip_N2', 'eventlevel_trip_N3',
       'eventlevel_trip_N4', 'eventlevel_trip_N5', 'eventlevel_trip_N6',
       'eventlevel_trip_N7A', 'eventtype_trip_P019 - Unconscious - syncope',
       'eventtype_trip_P039 - Cardiac problem (other than thoracic pain)']

y_var = 'total_time'

X = itv_reg[X_var]
y = itv_reg[y_var]
X = sm.add_constant(X)

model = sm.OLS(y, X.astype(float)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             total_time   R-squared:                       0.217
# Model:                            OLS   Adj. R-squared:                  0.216
# Method:                 Least Squares   F-statistic:                     272.9
# Date:                Sat, 04 May 2024   Prob (F-statistic):               0.00
# Time:                        19:15:42   Log-Likelihood:            -1.0580e+05
# No. Observations:               22651   AIC:                         2.116e+05
# Df Residuals:                   22627   BIC:                         2.118e+05
# Df Model:                          23
# Covariance Type:            nonrobust
# ====================================================================================================================================
#                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------
# const                                                               72.7558      2.056     35.380      0.000      68.725      76.786
# aed_distance                                                         0.0009      0.000      2.807      0.005       0.000       0.002
# hospital_distance                                                    0.0027   4.67e-05     58.423      0.000       0.003       0.003
# province_Brussels Hoofdstedelijk Gewest                              2.8917      0.544      5.317      0.000       1.826       3.958
# province_Henegouwen                                                  0.3658      0.558      0.655      0.512      -0.729       1.460
# province_Limburg                                                     2.1334      0.629      3.394      0.001       0.901       3.366
# province_Luik                                                       -1.9358      0.601     -3.219      0.001      -3.115      -0.757
# province_Luxemburg                                                  -0.9236      0.975     -0.947      0.343      -2.835       0.987
# province_Namen                                                      -0.3952      0.837     -0.472      0.637      -2.036       1.245
# province_Oost-Vlaanderen                                            -5.0707      9.160     -0.554      0.580     -23.025      12.884
# province_Vlaams-Brabant                                              3.6012      1.993      1.807      0.071      -0.306       7.508
# province_Waals-Brabant                                               4.5388      0.882      5.144      0.000       2.809       6.268
# province_West-Vlaanderen                                            -3.3543      9.783     -0.343      0.732     -22.529      15.820
# vector_type_MUG                                                     -2.0767      0.623     -3.332      0.001      -3.298      -0.855
# vector_type_PIT                                                      3.1206      0.690      4.525      0.000       1.769       4.472
# eventlevel_trip_N1                                                   1.8624      2.238      0.832      0.405      -2.524       6.249
# eventlevel_trip_N2                                                  -1.1629      2.396     -0.485      0.627      -5.859       3.533
# eventlevel_trip_N3                                                  -1.7778      2.323     -0.765      0.444      -6.331       2.775
# eventlevel_trip_N4                                                  -7.1526      2.296     -3.115      0.002     -11.653      -2.652
# eventlevel_trip_N5                                                 -10.1989      2.256     -4.520      0.000     -14.621      -5.777
# eventlevel_trip_N6                                                  -7.8871      4.193     -1.881      0.060     -16.106       0.331
# eventlevel_trip_N7A                                                 -0.5142     15.096     -0.034      0.973     -30.103      29.075
# eventtype_trip_P019 - Unconscious - syncope                        -12.7777      1.274    -10.027      0.000     -15.275     -10.280
# eventtype_trip_P039 - Cardiac problem (other than thoracic pain)   -11.2507      1.291     -8.715      0.000     -13.781      -8.720
# ==============================================================================
# Omnibus:                    18468.946   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1591241.931
# Skew:                           3.377   Prob(JB):                         0.00
# Kurtosis:                      43.502   Cond. No.                     5.74e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.74e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
## OLS regression on waiting_time

X = itv_reg[X_var]
y = itv_reg['waiting_time']
X = sm.add_constant(X)

model = sm.OLS(y, X.astype(float)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           waiting_time   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     54.16
# Date:                Sat, 04 May 2024   Prob (F-statistic):          5.26e-242
# Time:                        19:16:07   Log-Likelihood:                -81071.
# No. Observations:               22651   AIC:                         1.622e+05
# Df Residuals:                   22627   BIC:                         1.624e+05
# Df Model:                          23
# Covariance Type:            nonrobust
# ====================================================================================================================================
#                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------
# const                                                                9.8046      0.690     14.206      0.000       8.452      11.157
# aed_distance                                                         0.0009      0.000      7.622      0.000       0.001       0.001
# hospital_distance                                                    0.0003   1.57e-05     17.733      0.000       0.000       0.000
# province_Brussels Hoofdstedelijk Gewest                              1.9930      0.183     10.918      0.000       1.635       2.351
# province_Henegouwen                                                  1.2902      0.187      6.884      0.000       0.923       1.657
# province_Limburg                                                    -0.0686      0.211     -0.325      0.745      -0.482       0.345
# province_Luik                                                       -0.1581      0.202     -0.783      0.433      -0.554       0.238
# province_Luxemburg                                                  -0.4420      0.327     -1.351      0.177      -1.083       0.199
# province_Namen                                                      -0.4676      0.281     -1.665      0.096      -1.018       0.083
# province_Oost-Vlaanderen                                             0.9759      3.074      0.317      0.751      -5.050       7.002
# province_Vlaams-Brabant                                              7.8113      0.669     11.676      0.000       6.500       9.123
# province_Waals-Brabant                                               1.3321      0.296      4.498      0.000       0.752       1.913
# province_West-Vlaanderen                                             1.7231      3.283      0.525      0.600      -4.712       8.159
# vector_type_MUG                                                      3.3742      0.209     16.130      0.000       2.964       3.784
# vector_type_PIT                                                      1.8915      0.231      8.173      0.000       1.438       2.345
# eventlevel_trip_N1                                                   0.6843      0.751      0.911      0.362      -0.788       2.157
# eventlevel_trip_N2                                                   0.7675      0.804      0.955      0.340      -0.808       2.343
# eventlevel_trip_N3                                                   0.7247      0.780      0.930      0.353      -0.803       2.253
# eventlevel_trip_N4                                                   0.2956      0.771      0.384      0.701      -1.215       1.806
# eventlevel_trip_N5                                                   0.1703      0.757      0.225      0.822      -1.314       1.655
# eventlevel_trip_N6                                                   0.9905      1.407      0.704      0.482      -1.768       3.749
# eventlevel_trip_N7A                                                  8.1885      5.067      1.616      0.106      -1.742      18.119
# eventtype_trip_P019 - Unconscious - syncope                          0.0536      0.428      0.125      0.900      -0.785       0.892
# eventtype_trip_P039 - Cardiac problem (other than thoracic pain)     0.9645      0.433      2.226      0.026       0.115       1.814
# ==============================================================================
# Omnibus:                    25730.922   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          5315224.480
# Skew:                           5.639   Prob(JB):                         0.00
# Kurtosis:                      77.193   Cond. No.                     5.74e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.74e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
## OLS regression on time_to_hospital

X = itv_reg[X_var]
y = itv_reg['time_to_hospital']
X = sm.add_constant(X)

model = sm.OLS(y, X.astype(float)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       time_to_hospital   R-squared:                       0.240
# Model:                            OLS   Adj. R-squared:                  0.240
# Method:                 Least Squares   F-statistic:                     311.2
# Date:                Sat, 04 May 2024   Prob (F-statistic):               0.00
# Time:                        19:16:30   Log-Likelihood:                -95054.
# No. Observations:               22651   AIC:                         1.902e+05
# Df Residuals:                   22627   BIC:                         1.903e+05
# Df Model:                          23
# Covariance Type:            nonrobust
# ====================================================================================================================================
#                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------
# const                                                               42.3833      1.280     33.123      0.000      39.875      44.891
# aed_distance                                                         0.0013      0.000      5.978      0.000       0.001       0.002
# hospital_distance                                                    0.0016   2.91e-05     54.707      0.000       0.002       0.002
# province_Brussels Hoofdstedelijk Gewest                              3.3672      0.338      9.949      0.000       2.704       4.031
# province_Henegouwen                                                  2.3711      0.347      6.824      0.000       1.690       3.052
# province_Limburg                                                     1.6421      0.391      4.198      0.000       0.875       2.409
# province_Luik                                                        0.2130      0.374      0.569      0.569      -0.520       0.947
# province_Luxemburg                                                  -0.9284      0.607     -1.530      0.126      -2.118       0.261
# province_Namen                                                       1.3772      0.521      2.645      0.008       0.357       2.398
# province_Oost-Vlaanderen                                            -4.1490      5.700     -0.728      0.467     -15.321       7.023
# province_Vlaams-Brabant                                              8.2474      1.240      6.649      0.000       5.816      10.679
# province_Waals-Brabant                                               3.7763      0.549      6.878      0.000       2.700       4.852
# province_West-Vlaanderen                                             5.7956      6.087      0.952      0.341      -6.136      17.727
# vector_type_MUG                                                      6.0460      0.388     15.590      0.000       5.286       6.806
# vector_type_PIT                                                      4.0546      0.429      9.450      0.000       3.214       4.896
# eventlevel_trip_N1                                                   0.5962      1.393      0.428      0.669      -2.133       3.326
# eventlevel_trip_N2                                                  -0.9272      1.491     -0.622      0.534      -3.849       1.995
# eventlevel_trip_N3                                                  -1.7482      1.445     -1.210      0.226      -4.581       1.085
# eventlevel_trip_N4                                                  -5.6489      1.429     -3.954      0.000      -8.449      -2.849
# eventlevel_trip_N5                                                  -8.0904      1.404     -5.763      0.000     -10.842      -5.339
# eventlevel_trip_N6                                                  -5.7948      2.609     -2.221      0.026     -10.909      -0.681
# eventlevel_trip_N7A                                                  2.0861      9.393      0.222      0.824     -16.325      20.497
# eventtype_trip_P019 - Unconscious - syncope                         -6.9282      0.793     -8.738      0.000      -8.482      -5.374
# eventtype_trip_P039 - Cardiac problem (other than thoracic pain)    -5.5998      0.803     -6.971      0.000      -7.174      -4.025
# ==============================================================================
# Omnibus:                    27054.748   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         19996807.952
# Skew:                           5.694   Prob(JB):                         0.00
# Kurtosis:                     148.114   Cond. No.                     5.74e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.74e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
itv_aed['abandon_reason'].value_counts()
# Out:
# abandon_reason
# Weigering van vervoer    19
# Overleden                19
# Error                     7
# Verzorgd ter plaatse      6
# Weigering vervoer         4
# Geannuleerd               2
# Vervoerd door politie     2
# Vervoerd door derden      1
# Zonder patient            1
# Vervoer door derden       1
# Name: count, dtype: int64
