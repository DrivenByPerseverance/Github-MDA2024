# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
itv_aed = pd.read_csv(
    '/Users/lye/Downloads/MDA/Github-MDA2024/1_Data/CLEANED/intervention_aed_related_distance.csv',
    low_memory=False)

itv_aed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105841 entries, 0 to 105840
# Data columns (total 58 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   mission_id                        105841 non-null  int64
#  1   service_name                      93471 non-null   object
#  2   postalcode_permanence             65151 non-null   float64
#  3   cityname_permanence               69218 non-null   object
#  4   streetname_permanence             69623 non-null   object
#  5   housenumber_permanence            2667 non-null    float64
#  6   latitude_permanence               97007 non-null   float64
#  7   longitude_permanence              97690 non-null   float64
#  8   permanence_short_name             105670 non-null  object
#  9   permanence_long_name              93486 non-null   object
#  10  vector_type                       104009 non-null  object
#  11  eventtype_firstcall               65569 non-null   object
#  12  eventlevel_firstcall              65446 non-null   object
#  13  eventtype_trip                    105841 non-null  object
#  14  eventlevel_trip                   105830 non-null  object
#  15  postalcode_intervention           0 non-null       float64
#  16  cityname_intervention             105831 non-null  object
#  17  lat_itv                           105841 non-null  float64
#  18  lon_itv                           105841 non-null  float64
#  19  t0                                105548 non-null  object
#  20  t1                                103974 non-null  object
#  21  t1confirmed                       63228 non-null   object
#  22  t2                                95663 non-null   object
#  23  t3                                90823 non-null   object
#  24  t4                                72427 non-null   object
#  25  t5                                62161 non-null   object
#  26  t6                                84697 non-null   object
#  27  t7                                67215 non-null   object
#  28  t9                                4 non-null       object
#  29  intervention_time_(t1reported)    89706 non-null   float64
#  30  waiting_time                      57572 non-null   float64
#  31  intervention_duration             50080 non-null   float64
#  32  departure_time_(t1reported)       94379 non-null   float64
#  33  unavailable_time                  3 non-null       float64
#  34  name_destination_hospital         62362 non-null   object
#  35  postalcode_destination_hospital   1 non-null       float64
#  36  cityname_destination_hospital     37629 non-null   object
#  37  streetname_destination_hospital   37588 non-null   object
#  38  housenumber_destination_hospital  0 non-null       float64
#  39  calculated_traveltime_destinatio  31827 non-null   float64
#  40  calculated_distance_destination   31827 non-null   float64
#  41  number_of_transported_persons     32193 non-null   float64
#  42  abandon_reason                    11538 non-null   object
#  43  t0_Hour                           105548 non-null  float64
#  44  t0_Day                            105548 non-null  float64
#  45  t0_Month                          105548 non-null  float64
#  46  t0_Year                           105548 non-null  float64
#  47  t0_DayName                        105548 non-null  object
#  48  t7_Hour                           67215 non-null   float64
#  49  t7_Day                            67215 non-null   float64
#  50  t7_Month                          67215 non-null   float64
#  51  t7_Year                           67215 non-null   float64
#  52  t7_DayName                        67215 non-null   object
#  53  province                          105841 non-null  object
#  54  intervention_time_(t1confirmed)   59473 non-null   float64
#  55  departure_time_(t1confirmed)      62215 non-null   float64
#  56  aed_distance                      105841 non-null  float64
#  57  hospital_distance                 105841 non-null  float64
# dtypes: float64(29), int64(1), object(28)
# memory usage: 46.8+ MB

# %%
aed = pd.read_csv('/Users/lye/Downloads/MDA/Github-MDA2024/1_Data/CLEANED/aed_location_latlon.csv')

aed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15775 entries, 0 to 15774
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            15775 non-null  float64
#  1   type          5661 non-null   object
#  2   address       15775 non-null  object
#  3   number        13577 non-null  float64
#  4   postal_code   15775 non-null  int64
#  5   municipality  15775 non-null  object
#  6   province      15775 non-null  object
#  7   location      8962 non-null   object
#  8   public        8656 non-null   object
#  9   available     4739 non-null   object
#  10  hours         1148 non-null   object
#  11  full_address  15775 non-null  object
#  12  lat           15775 non-null  float64
#  13  lon           15775 non-null  float64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 1.7+ MB

# %%
itv_aed.drop_duplicates(subset=['mission_id'], keep='first', inplace=True)
itv_aed.drop_duplicates(subset=['lat_itv', 'lon_itv'], keep='first', inplace=True)
itv_aed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58901 entries, 0 to 105839
# Data columns (total 58 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   mission_id                        58901 non-null  int64
#  1   service_name                      51811 non-null  object
#  2   postalcode_permanence             36008 non-null  float64
#  3   cityname_permanence               38572 non-null  object
#  4   streetname_permanence             38721 non-null  object
#  5   housenumber_permanence            1535 non-null   float64
#  6   latitude_permanence               54192 non-null  float64
#  7   longitude_permanence              54547 non-null  float64
#  8   permanence_short_name             58772 non-null  object
#  9   permanence_long_name              51821 non-null  object
#  10  vector_type                       57728 non-null  object
#  11  eventtype_firstcall               36166 non-null  object
#  12  eventlevel_firstcall              36092 non-null  object
#  13  eventtype_trip                    58901 non-null  object
#  14  eventlevel_trip                   58892 non-null  object
#  15  postalcode_intervention           0 non-null      float64
#  16  cityname_intervention             58896 non-null  object
#  17  lat_itv                           58901 non-null  float64
#  18  lon_itv                           58901 non-null  float64
#  19  t0                                58738 non-null  object
#  20  t1                                57717 non-null  object
#  21  t1confirmed                       35563 non-null  object
#  22  t2                                53374 non-null  object
#  23  t3                                50992 non-null  object
#  24  t4                                41915 non-null  object
#  25  t5                                36555 non-null  object
#  26  t6                                47134 non-null  object
#  27  t7                                36814 non-null  object
#  28  t9                                2 non-null      object
#  29  intervention_time_(t1reported)    50220 non-null  float64
#  30  waiting_time                      32160 non-null  float64
#  31  intervention_duration             27781 non-null  float64
#  32  departure_time_(t1reported)       52496 non-null  float64
#  33  unavailable_time                  0 non-null      float64
#  34  name_destination_hospital         38132 non-null  object
#  35  postalcode_destination_hospital   0 non-null      float64
#  36  cityname_destination_hospital     24007 non-null  object
#  37  streetname_destination_hospital   23975 non-null  object
#  38  housenumber_destination_hospital  0 non-null      float64
#  39  calculated_traveltime_destinatio  20134 non-null  float64
#  40  calculated_distance_destination   20134 non-null  float64
#  41  number_of_transported_persons     22284 non-null  float64
#  42  abandon_reason                    7066 non-null   object
#  43  t0_Hour                           58738 non-null  float64
#  44  t0_Day                            58738 non-null  float64
#  45  t0_Month                          58738 non-null  float64
#  46  t0_Year                           58738 non-null  float64
#  47  t0_DayName                        58738 non-null  object
#  48  t7_Hour                           36814 non-null  float64
#  49  t7_Day                            36814 non-null  float64
#  50  t7_Month                          36814 non-null  float64
#  51  t7_Year                           36814 non-null  float64
#  52  t7_DayName                        36814 non-null  object
#  53  province                          58901 non-null  object
#  54  intervention_time_(t1confirmed)   33871 non-null  float64
#  55  departure_time_(t1confirmed)      35117 non-null  float64
#  56  aed_distance                      58901 non-null  float64
#  57  hospital_distance                 58901 non-null  float64
# dtypes: float64(29), int64(1), object(28)
# memory usage: 26.5+ MB

# %%
speed_running = 100 # m/min  average running speed = 6 km/h
speed_driving = 500 # m/min  average driving speed = 30 km/h (urban area in Belgium)
golden_minutes = 4 # best interval for cpr using AED

itv_covered = itv_aed.loc[((itv_aed['aed_distance']<=speed_running * golden_minutes / 2) |
                           (itv_aed['hospital_distance']<=speed_driving * golden_minutes))]

itv_covered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27738 entries, 0 to 105836
# Data columns (total 58 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   mission_id                        27738 non-null  int64
#  1   service_name                      25047 non-null  object
#  2   postalcode_permanence             18008 non-null  float64
#  3   cityname_permanence               20139 non-null  object
#  4   streetname_permanence             20192 non-null  object
#  5   housenumber_permanence            557 non-null    float64
#  6   latitude_permanence               25406 non-null  float64
#  7   longitude_permanence              25587 non-null  float64
#  8   permanence_short_name             27636 non-null  object
#  9   permanence_long_name              25057 non-null  object
#  10  vector_type                       26807 non-null  object
#  11  eventtype_firstcall               18072 non-null  object
#  12  eventlevel_firstcall              18029 non-null  object
#  13  eventtype_trip                    27738 non-null  object
#  14  eventlevel_trip                   27733 non-null  object
#  15  postalcode_intervention           0 non-null      float64
#  16  cityname_intervention             27737 non-null  object
#  17  lat_itv                           27738 non-null  float64
#  18  lon_itv                           27738 non-null  float64
#  19  t0                                27663 non-null  object
#  20  t1                                26801 non-null  object
#  21  t1confirmed                       15163 non-null  object
#  22  t2                                24626 non-null  object
#  23  t3                                23289 non-null  object
#  24  t4                                18830 non-null  object
#  25  t5                                16591 non-null  object
#  26  t6                                20775 non-null  object
#  27  t7                                18136 non-null  object
#  28  t9                                2 non-null      object
#  29  intervention_time_(t1reported)    22397 non-null  float64
#  30  waiting_time                      15656 non-null  float64
#  31  intervention_duration             13070 non-null  float64
#  32  departure_time_(t1reported)       23623 non-null  float64
#  33  unavailable_time                  0 non-null      float64
#  34  name_destination_hospital         17436 non-null  object
#  35  postalcode_destination_hospital   0 non-null      float64
#  36  cityname_destination_hospital     12174 non-null  object
#  37  streetname_destination_hospital   12159 non-null  object
#  38  housenumber_destination_hospital  0 non-null      float64
#  39  calculated_traveltime_destinatio  10120 non-null  float64
#  40  calculated_distance_destination   10120 non-null  float64
#  41  number_of_transported_persons     11574 non-null  float64
#  42  abandon_reason                    3978 non-null   object
#  43  t0_Hour                           27663 non-null  float64
#  44  t0_Day                            27663 non-null  float64
#  45  t0_Month                          27663 non-null  float64
#  46  t0_Year                           27663 non-null  float64
#  47  t0_DayName                        27663 non-null  object
#  48  t7_Hour                           18136 non-null  float64
#  49  t7_Day                            18136 non-null  float64
#  50  t7_Month                          18136 non-null  float64
#  51  t7_Year                           18136 non-null  float64
#  52  t7_DayName                        18136 non-null  object
#  53  province                          27738 non-null  object
#  54  intervention_time_(t1confirmed)   14392 non-null  float64
#  55  departure_time_(t1confirmed)      14925 non-null  float64
#  56  aed_distance                      27738 non-null  float64
#  57  hospital_distance                 27738 non-null  float64
# dtypes: float64(29), int64(1), object(28)
# memory usage: 12.5+ MB

# %%
## Coverage of AEDs and hospitals

coverage = len(itv_covered) / len(itv_aed)
coverage
# Out:
# 0.47092579073360386

# %%
itv_uncovered = itv_aed.loc[~(
    (itv_aed['aed_distance'] <= speed_running * golden_minutes / 2) |
    (itv_aed['hospital_distance'] <= speed_driving * golden_minutes))]

itv_uncovered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31163 entries, 15 to 105839
# Data columns (total 58 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   mission_id                        31163 non-null  int64
#  1   service_name                      26764 non-null  object
#  2   postalcode_permanence             18000 non-null  float64
#  3   cityname_permanence               18433 non-null  object
#  4   streetname_permanence             18529 non-null  object
#  5   housenumber_permanence            978 non-null    float64
#  6   latitude_permanence               28786 non-null  float64
#  7   longitude_permanence              28960 non-null  float64
#  8   permanence_short_name             31136 non-null  object
#  9   permanence_long_name              26764 non-null  object
#  10  vector_type                       30921 non-null  object
#  11  eventtype_firstcall               18094 non-null  object
#  12  eventlevel_firstcall              18063 non-null  object
#  13  eventtype_trip                    31163 non-null  object
#  14  eventlevel_trip                   31159 non-null  object
#  15  postalcode_intervention           0 non-null      float64
#  16  cityname_intervention             31159 non-null  object
#  17  lat_itv                           31163 non-null  float64
#  18  lon_itv                           31163 non-null  float64
#  19  t0                                31075 non-null  object
#  20  t1                                30916 non-null  object
#  21  t1confirmed                       20400 non-null  object
#  22  t2                                28748 non-null  object
#  23  t3                                27703 non-null  object
#  24  t4                                23085 non-null  object
#  25  t5                                19964 non-null  object
#  26  t6                                26359 non-null  object
#  27  t7                                18678 non-null  object
#  28  t9                                0 non-null      object
#  29  intervention_time_(t1reported)    27823 non-null  float64
#  30  waiting_time                      16504 non-null  float64
#  31  intervention_duration             14711 non-null  float64
#  32  departure_time_(t1reported)       28873 non-null  float64
#  33  unavailable_time                  0 non-null      float64
#  34  name_destination_hospital         20696 non-null  object
#  35  postalcode_destination_hospital   0 non-null      float64
#  36  cityname_destination_hospital     11833 non-null  object
#  37  streetname_destination_hospital   11816 non-null  object
#  38  housenumber_destination_hospital  0 non-null      float64
#  39  calculated_traveltime_destinatio  10014 non-null  float64
#  40  calculated_distance_destination   10014 non-null  float64
#  41  number_of_transported_persons     10710 non-null  float64
#  42  abandon_reason                    3088 non-null   object
#  43  t0_Hour                           31075 non-null  float64
#  44  t0_Day                            31075 non-null  float64
#  45  t0_Month                          31075 non-null  float64
#  46  t0_Year                           31075 non-null  float64
#  47  t0_DayName                        31075 non-null  object
#  48  t7_Hour                           18678 non-null  float64
#  49  t7_Day                            18678 non-null  float64
#  50  t7_Month                          18678 non-null  float64
#  51  t7_Year                           18678 non-null  float64
#  52  t7_DayName                        18678 non-null  object
#  53  province                          31163 non-null  object
#  54  intervention_time_(t1confirmed)   19479 non-null  float64
#  55  departure_time_(t1confirmed)      20192 non-null  float64
#  56  aed_distance                      31163 non-null  float64
#  57  hospital_distance                 31163 non-null  float64
# dtypes: float64(29), int64(1), object(28)
# memory usage: 14.0+ MB

# %%
## Use KMeans to find the optimal location for AEDs

kmeans = KMeans(n_clusters=aed.shape[0], random_state=0).fit(itv_aed[['lat_itv', 'lon_itv']])

aed[['new_lat', 'new_lon']] = kmeans.cluster_centers_
aed.head()
# Out:
#      id type              address  number  postal_code municipality province  \
# 0  13.0  NaN  Blvd. fr. roosevelt    24.0         7060     Soignies  Hainaut
# 1  70.0  NaN      Ch. de wégimont    76.0         4630      Ayeneux    Liège
# 2  71.0  NaN  Place saint-lambert     NaN         4020        Liège    Liège
# 3  72.0  NaN        Rue du doyard     NaN         4990     Lierneux    Liège
# 4  73.0  NaN   Fond saint servais     NaN         4000        Liège    Liège
#
#   location public available hours  \
# 0      NaN      Y       NaN   NaN
# 1      NaN    NaN       NaN   NaN
# 2      NaN    NaN       NaN   NaN
# 3      NaN    NaN       NaN   NaN
# 4      NaN    NaN       NaN   NaN
#
#                                   full_address        lat       lon  \
# 0  Blvd. fr. roosevelt, 7060 Soignies, Hainaut  50.576042  4.065740
# 1         Ch. de wégimont, 4630 Ayeneux, Liège  50.607680  5.730187
# 2       Place saint-lambert, 4020 Liège, Liège  50.645622  5.573620
# 3          Rue du doyard, 4990 Lierneux, Liège  50.287416  5.786325
# 4        Fond saint servais, 4000 Liège, Liège  50.646806  5.571031
#
#      new_lat   new_lon
# 0  51.061387  5.072847
# 1  51.038101  3.737019
# 2  50.838041  4.443571
# 3  50.596113  5.504008
# 4  51.059662  2.893200

# %%
# Calculate distance between itervention and new AED locations

from pyproj import Geod

geod = Geod(ellps='WGS84')


def find_closest_distance(df1, df2):
    distances = []
    for index1, row1 in df1.iterrows():
        min_distance = float('inf')
        for index2, row2 in df2.iterrows():
            # calculate the distance between two points
            _, _, distance = geod.inv(row1['lon_itv'], row1['lat_itv'],
                                      row2['new_lon'], row2['new_lat'])
            # update the min distance
            if distance < min_distance:
                min_distance = distance
        # append the min distance to the list
        distances.append(min_distance)
    return distances

itv_aed['new_aed_distance'] = find_closest_distance(itv_aed, aed)
itv_aed.head()
# Out:
#     mission_id                   service_name  postalcode_permanence  \
# 0  20222490015  FB PDS BRUX [PASI CitÈ] SIAMU                 1000.0
# 1  20222490041       HB UR BRUX CHU St Pierre                 1000.0
# 3  20222490042  FB PDS BRUX [PASI CitÈ] SIAMU                 1000.0
# 4  20222490045            BB FORE Croix Rouge                 1190.0
# 5  20222490053       HB UR BRUX Europe Michel                 1040.0
#
#      cityname_permanence  streetname_permanence  housenumber_permanence  \
# 0      Brussel (Brussel)         Vesaliusstraat                     NaN
# 1      Brussel (Brussel)              Rue Haute                     NaN
# 3      Brussel (Brussel)         Vesaliusstraat                     NaN
# 4          Vorst (Vorst)            Rue Marconi                     NaN
# 5  Etterbeek (Etterbeek)  Charles Degrouxstraat                     NaN
#
#    latitude_permanence  longitude_permanence permanence_short_name  \
# 0             50.85097              4.364110             ABBRUX03A
# 1             50.83433              4.345450             ABBRUX08A
# 3             50.85097              4.364110             ABBRUX11A
# 4             50.81598              4.341524             ABFORE01A
# 5             50.84226              4.399250             ABETTE01A
#
#   permanence_long_name  ... t7_Day t7_Month t7_Year t7_DayName  \
# 0           AMB HELI 3  ...    6.0      9.0  2022.0    Tuesday
# 1            AMB HSP 3  ...    6.0      9.0  2022.0    Tuesday
# 3           AMB CITE 2  ...    NaN      NaN     NaN        NaN
# 4         AMB FOREST 1  ...    6.0      9.0  2022.0    Tuesday
# 5        AMB ST MICHEL  ...    6.0      9.0  2022.0    Tuesday
#
#                          province  intervention_time_(t1confirmed)  \
# 0  Brussels Hoofdstedelijk Gewest                              NaN
# 1  Brussels Hoofdstedelijk Gewest                              NaN
# 3  Brussels Hoofdstedelijk Gewest                              NaN
# 4  Brussels Hoofdstedelijk Gewest                              NaN
# 5  Brussels Hoofdstedelijk Gewest                              NaN
#
#   departure_time_(t1confirmed)  aed_distance  hospital_distance  \
# 0                          NaN     61.129528         465.046464
# 1                          NaN     71.815838         773.845722
# 3                          NaN     95.336554        1529.142400
# 4                          NaN    165.716925        1306.596211
# 5                          NaN    149.195110         566.010100
#
#   new_aed_distance
# 0        92.988766
# 1        40.126455
# 3        79.125488
# 4        71.867132
# 5       151.673684
#
# [5 rows x 59 columns]

# %%
## Cvoverage after kmeans optimization

kmeans_covered = itv_aed.loc[(
    (itv_aed['new_aed_distance'] <= speed_running * golden_minutes / 2) |
    (itv_aed['hospital_distance'] <= speed_driving * golden_minutes))]

coverage = len(kmeans_covered) / len(itv_aed)
coverage
# Out:
# 0.8376428244002648

# %%
## Add province information to the new AED locations

import geopandas as gpd
from shapely import geometry as geo
from shapely.validation import explain_validity

geo_path = '/Users/lye/Downloads/MDA/Github-MDA2024/1_Data/Belgium.provinces.WGS84.geojson'
geo_be = gpd.read_file(geo_path)

# Check if the geometries are valid
for i in range(len(geo_be)):
    if not geo_be.loc[i, 'geometry'].is_valid:
        print(explain_validity(geo_be.loc[i, 'geometry']))
        geo_be.loc[i, 'geometry'] = geo_be.loc[i, 'geometry'].buffer(0)
        print(geo_be.loc[i, 'geometry'].is_valid)
# Out:
# Self-intersection[6.24760990547934 50.640636186645]
# True

# %%
def get_medical_province(df, geo_df):
    province = []
    missing_province = 0
    for i in range(len(df)):
        point = geo.Point(df.loc[i, 'new_lon'], df.loc[i, 'new_lat'])
        contained = geo_df.loc[geo_df['geometry'].contains(
            point)]['NameDUT'].values
        if contained.size > 0:
            province.append(contained[0])
        else:
            province.append(None)
            missing_province += 1

    df['new_province'] = province
    print(f'{missing_province} coordinates are not located in any province')

    return df


aed = get_medical_province(aed, geo_be)
aed['new_province'].value_counts()
# Out:
# 0 coordinates are not located in any province
# new_province
# Provincie Antwerpen               2245
# Provincie Oost-Vlaanderen         2216
# Provincie Henegouwen              1952
# Provincie West-Vlaanderen         1890
# Provincie Vlaams-Brabant          1738
# Provincie Luik                    1501
# Provincie Limburg                 1369
# Provincie Namen                    885
# Brussels Hoofdstedelijk Gewest     743
# Provincie Luxemburg                663
# Provincie Waals-Brabant            573
# Name: count, dtype: int64

# %%
aed['province'].value_counts()
# Out:
# province
# Antwerpen            2355
# Bruxelles-brussel    2117
# Hainaut              1950
# Liège                1771
# Oost-vlaanderen      1664
# West-vlaanderen      1374
# Vlaams-brabant       1282
# Limburg               998
# Namur                 900
# Luxembourg            683
# Brabant wallon        681
# Name: count, dtype: int64

# %%
itv_uncovered.to_csv('/Users/lye/Downloads/MDA/Github-MDA2024/1_Data/CLEANED/intervention_uncovered.csv', index=False)
aed.to_csv('/Users/lye/Downloads/MDA/Github-MDA2024/1_Data/CLEANED/aed_with_KmeansLocation.csv', index=False)
itv_aed.to_csv('/Users/lye/Downloads/MDA/Github-MDA2024/1_Data/CLEANED/intervention_aed_kmeans_distance.csv', index=False)
