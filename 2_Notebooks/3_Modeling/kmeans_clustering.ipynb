# %% [markdown]
# #### Generate new AED locations using clustering technique
#
# In this notebook, we calculated the coverage of medical facilities for the AED related interventions (`P003-Cardiac arrest` and `P039-Cardiac problem(other than thoracic pain)`). According to the golden 4 minutes for CPR, we assume that a patient is covered by medical facilities if he can get an AED device or goes to hospital within 4 minutes. And we also assume that the walking speed is 100m/min and driving speed is 500m/min. Thus, if an AED is located within 200m (go and get the AED back by walking) of a patient or a hospital is within 2000m (drive to the hospital) of the patient, the patient is covered(`1`) by medical facilities, otherwise not covered(`0`). The initial coverage rate of the AED related intervention is 42.7%. We used Kmeans to cluster the interventions as n clusters, where n is the number of AEDs we have, and used the centers of clusters as the new AED locations. After this process, the new coverage rate increases to 99.6%.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
itv_aed = pd.read_csv(
    '/Users/lye/Downloads/MDA/Github-MDA2024/1_Data/CLEANED/intervention_aed_related_distance.csv',
    low_memory=False)

itv_aed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43093 entries, 0 to 43092
# Data columns (total 56 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   mission_id                        43093 non-null  int64
#  1   service_name                      38978 non-null  object
#  2   postalcode_permanence             27284 non-null  float64
#  3   cityname_permanence               28483 non-null  object
#  4   streetname_permanence             28631 non-null  object
#  5   housenumber_permanence            2156 non-null   float64
#  6   latitude_permanence               39916 non-null  float64
#  7   longitude_permanence              40255 non-null  float64
#  8   permanence_short_name             43053 non-null  object
#  9   permanence_long_name              38982 non-null  object
#  10  vector_type                       42545 non-null  object
#  11  eventtype_firstcall               27434 non-null  object
#  12  eventlevel_firstcall              27399 non-null  object
#  13  eventtype_trip                    43093 non-null  object
#  14  eventlevel_trip                   43084 non-null  object
#  15  postalcode_intervention           4129 non-null   float64
#  16  cityname_intervention             43088 non-null  object
#  17  lat_itv                           43093 non-null  float64
#  18  lon_itv                           43093 non-null  float64
#  19  t0                                43010 non-null  object
#  20  t1                                42545 non-null  object
#  21  t1confirmed                       27180 non-null  object
#  22  t2                                39451 non-null  object
#  23  t3                                37998 non-null  object
#  24  t4                                30082 non-null  object
#  25  t5                                26673 non-null  object
#  26  t6                                35539 non-null  object
#  27  t7                                23680 non-null  object
#  28  t9                                1 non-null      object
#  29  intervention_time_(t1reported)    37673 non-null  float64
#  30  waiting_time                      24690 non-null  float64
#  31  intervention_duration             21472 non-null  float64
#  32  departure_time_(t1reported)       39211 non-null  float64
#  33  unavailable_time                  2 non-null      float64
#  34  name_destination_hospital         25086 non-null  object
#  35  postalcode_destination_hospital   2068 non-null   float64
#  36  cityname_destination_hospital     15656 non-null  object
#  37  streetname_destination_hospital   15638 non-null  object
#  38  housenumber_destination_hospital  1689 non-null   float64
#  39  calculated_traveltime_destinatio  13255 non-null  float64
#  40  calculated_distance_destination   13255 non-null  float64
#  41  number_of_transported_persons     13465 non-null  float64
#  42  abandon_reason                    4483 non-null   object
#  43  t0_Hour                           43010 non-null  float64
#  44  t0_Day                            43010 non-null  float64
#  45  t0_Month                          43010 non-null  float64
#  46  t0_DayName                        43010 non-null  object
#  47  t7_Hour                           23680 non-null  float64
#  48  t7_Day                            23680 non-null  float64
#  49  t7_Month                          23680 non-null  float64
#  50  t7_DayName                        23680 non-null  object
#  51  province                          43093 non-null  object
#  52  intervention_time_(t1confirmed)   25840 non-null  float64
#  53  departure_time_(t1confirmed)      26794 non-null  float64
#  54  aed_distance                      43093 non-null  float64
#  55  hospital_distance                 43093 non-null  float64
# dtypes: float64(27), int64(1), object(28)
# memory usage: 18.4+ MB

# %%
aed = pd.read_csv('/Users/lye/Downloads/MDA/Github-MDA2024/1_Data/CLEANED/aed_location_latlon.csv')

aed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15775 entries, 0 to 15774
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            15775 non-null  float64
#  1   type          5661 non-null   object
#  2   address       15775 non-null  object
#  3   number        13577 non-null  float64
#  4   postal_code   15775 non-null  int64
#  5   municipality  15775 non-null  object
#  6   province      15775 non-null  object
#  7   location      8962 non-null   object
#  8   public        8656 non-null   object
#  9   available     4739 non-null   object
#  10  hours         1148 non-null   object
#  11  full_address  15775 non-null  object
#  12  lat           15775 non-null  float64
#  13  lon           15775 non-null  float64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 1.7+ MB

# %%
## drop duplicates mission_id and location of aed_related_interventions 

itv_aed.drop_duplicates(subset=['mission_id'], keep='first', inplace=True)
itv_aed.drop_duplicates(subset=['lat_itv', 'lon_itv'], keep='first', inplace=True)
itv_aed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25381 entries, 0 to 43091
# Data columns (total 56 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   mission_id                        25381 non-null  int64
#  1   service_name                      22837 non-null  object
#  2   postalcode_permanence             16087 non-null  float64
#  3   cityname_permanence               16830 non-null  object
#  4   streetname_permanence             16878 non-null  object
#  5   housenumber_permanence            1366 non-null   float64
#  6   latitude_permanence               23546 non-null  float64
#  7   longitude_permanence              23741 non-null  float64
#  8   permanence_short_name             25350 non-null  object
#  9   permanence_long_name              22839 non-null  object
#  10  vector_type                       25049 non-null  object
#  11  eventtype_firstcall               16135 non-null  object
#  12  eventlevel_firstcall              16109 non-null  object
#  13  eventtype_trip                    25381 non-null  object
#  14  eventlevel_trip                   25373 non-null  object
#  15  postalcode_intervention           2222 non-null   float64
#  16  cityname_intervention             25378 non-null  object
#  17  lat_itv                           25381 non-null  float64
#  18  lon_itv                           25381 non-null  float64
#  19  t0                                25331 non-null  object
#  20  t1                                25049 non-null  object
#  21  t1confirmed                       16246 non-null  object
#  22  t2                                23369 non-null  object
#  23  t3                                22582 non-null  object
#  24  t4                                18489 non-null  object
#  25  t5                                16704 non-null  object
#  26  t6                                20968 non-null  object
#  27  t7                                13923 non-null  object
#  28  t9                                0 non-null      object
#  29  intervention_time_(t1reported)    22374 non-null  float64
#  30  waiting_time                      14654 non-null  float64
#  31  intervention_duration             12712 non-null  float64
#  32  departure_time_(t1reported)       23207 non-null  float64
#  33  unavailable_time                  0 non-null      float64
#  34  name_destination_hospital         16541 non-null  object
#  35  postalcode_destination_hospital   1276 non-null   float64
#  36  cityname_destination_hospital     10646 non-null  object
#  37  streetname_destination_hospital   10630 non-null  object
#  38  housenumber_destination_hospital  1045 non-null   float64
#  39  calculated_traveltime_destinatio  8937 non-null   float64
#  40  calculated_distance_destination   8937 non-null   float64
#  41  number_of_transported_persons     9833 non-null   float64
#  42  abandon_reason                    2850 non-null   object
#  43  t0_Hour                           25331 non-null  float64
#  44  t0_Day                            25331 non-null  float64
#  45  t0_Month                          25331 non-null  float64
#  46  t0_DayName                        25331 non-null  object
#  47  t7_Hour                           13923 non-null  float64
#  48  t7_Day                            13923 non-null  float64
#  49  t7_Month                          13923 non-null  float64
#  50  t7_DayName                        13923 non-null  object
#  51  province                          25381 non-null  object
#  52  intervention_time_(t1confirmed)   15586 non-null  float64
#  53  departure_time_(t1confirmed)      16080 non-null  float64
#  54  aed_distance                      25381 non-null  float64
#  55  hospital_distance                 25381 non-null  float64
# dtypes: float64(27), int64(1), object(28)
# memory usage: 11.0+ MB

# %%
speed_running = 100 # m/min  average running speed = 6 km/h
speed_driving = 500 # m/min  average driving speed = 30 km/h (urban area in Belgium)
golden_minutes = 4 # best interval for cpr using AED

itv_covered = itv_aed.loc[((itv_aed['aed_distance']<=speed_running * golden_minutes / 2) |
                           (itv_aed['hospital_distance']<=speed_driving * golden_minutes))]

itv_covered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10837 entries, 0 to 43064
# Data columns (total 56 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   mission_id                        10837 non-null  int64
#  1   service_name                      9959 non-null   object
#  2   postalcode_permanence             7344 non-null   float64
#  3   cityname_permanence               7935 non-null   object
#  4   streetname_permanence             7951 non-null   object
#  5   housenumber_permanence            726 non-null    float64
#  6   latitude_permanence               10070 non-null  float64
#  7   longitude_permanence              10148 non-null  float64
#  8   permanence_short_name             10816 non-null  object
#  9   permanence_long_name              9961 non-null   object
#  10  vector_type                       10589 non-null  object
#  11  eventtype_firstcall               7362 non-null   object
#  12  eventlevel_firstcall              7351 non-null   object
#  13  eventtype_trip                    10837 non-null  object
#  14  eventlevel_trip                   10833 non-null  object
#  15  postalcode_intervention           1716 non-null   float64
#  16  cityname_intervention             10837 non-null  object
#  17  lat_itv                           10837 non-null  float64
#  18  lon_itv                           10837 non-null  float64
#  19  t0                                10819 non-null  object
#  20  t1                                10589 non-null  object
#  21  t1confirmed                       6509 non-null   object
#  22  t2                                9846 non-null   object
#  23  t3                                9465 non-null   object
#  24  t4                                7629 non-null   object
#  25  t5                                6885 non-null   object
#  26  t6                                8424 non-null   object
#  27  t7                                6449 non-null   object
#  28  t9                                0 non-null      object
#  29  intervention_time_(t1reported)    9191 non-null   float64
#  30  waiting_time                      6578 non-null   float64
#  31  intervention_duration             5472 non-null   float64
#  32  departure_time_(t1reported)       9587 non-null   float64
#  33  unavailable_time                  0 non-null      float64
#  34  name_destination_hospital         6857 non-null   object
#  35  postalcode_destination_hospital   972 non-null    float64
#  36  cityname_destination_hospital     4864 non-null   object
#  37  streetname_destination_hospital   4860 non-null   object
#  38  housenumber_destination_hospital  785 non-null    float64
#  39  calculated_traveltime_destinatio  4064 non-null   float64
#  40  calculated_distance_destination   4064 non-null   float64
#  41  number_of_transported_persons     4555 non-null   float64
#  42  abandon_reason                    1332 non-null   object
#  43  t0_Hour                           10819 non-null  float64
#  44  t0_Day                            10819 non-null  float64
#  45  t0_Month                          10819 non-null  float64
#  46  t0_DayName                        10819 non-null  object
#  47  t7_Hour                           6449 non-null   float64
#  48  t7_Day                            6449 non-null   float64
#  49  t7_Month                          6449 non-null   float64
#  50  t7_DayName                        6449 non-null   object
#  51  province                          10837 non-null  object
#  52  intervention_time_(t1confirmed)   6227 non-null   float64
#  53  departure_time_(t1confirmed)      6407 non-null   float64
#  54  aed_distance                      10837 non-null  float64
#  55  hospital_distance                 10837 non-null  float64
# dtypes: float64(27), int64(1), object(28)
# memory usage: 4.7+ MB

# %%
## Coverage of AEDs and hospitals

coverage = len(itv_covered) / len(itv_aed)
print('Coverage of AEDs and hospitals:', coverage)
# Out:
# Coverage of AEDs and hospitals: 0.4269729325085694

# %%
## Use KMeans to find the optimal location for AEDs

kmeans = KMeans(n_clusters=aed.shape[0], random_state=0).fit(itv_aed[['lat_itv', 'lon_itv']])

aed[['new_lat', 'new_lon']] = kmeans.cluster_centers_
aed.head()
# Out:
#      id type              address  number  postal_code municipality province  \
# 0  13.0  NaN  Blvd. fr. roosevelt    24.0         7060     Soignies  Hainaut
# 1  70.0  NaN      Ch. de wégimont    76.0         4630      Ayeneux    Liège
# 2  71.0  NaN  Place saint-lambert     NaN         4020        Liège    Liège
# 3  72.0  NaN        Rue du doyard     NaN         4990     Lierneux    Liège
# 4  73.0  NaN   Fond saint servais     NaN         4000        Liège    Liège
#
#   location public available hours  \
# 0      NaN      Y       NaN   NaN
# 1      NaN    NaN       NaN   NaN
# 2      NaN    NaN       NaN   NaN
# 3      NaN    NaN       NaN   NaN
# 4      NaN    NaN       NaN   NaN
#
#                                   full_address        lat       lon  \
# 0  Blvd. fr. roosevelt, 7060 Soignies, Hainaut  50.576042  4.065740
# 1         Ch. de wégimont, 4630 Ayeneux, Liège  50.607680  5.730187
# 2       Place saint-lambert, 4020 Liège, Liège  50.645622  5.573620
# 3          Rue du doyard, 4990 Lierneux, Liège  50.287416  5.786325
# 4        Fond saint servais, 4000 Liège, Liège  50.646806  5.571031
#
#      new_lat   new_lon
# 0  50.924320  5.253690
# 1  50.892865  4.075619
# 2  51.183575  3.141258
# 3  50.415840  4.876835
# 4  51.159505  4.485365

# %%
# Calculate distance between itervention and the nearest new AED location

from pyproj import Geod

geod = Geod(ellps='WGS84')


def find_closest_distance(df1, df2):
    distances = []
    for index1, row1 in df1.iterrows():
        min_distance = float('inf')
        for index2, row2 in df2.iterrows():
            # calculate the distance between two points
            _, _, distance = geod.inv(row1['lon_itv'], row1['lat_itv'],
                                      row2['new_lon'], row2['new_lat'])
            # update the min distance
            if distance < min_distance:
                min_distance = distance
        # append the min distance to the list
        distances.append(min_distance)
    return distances

itv_aed['new_aed_distance'] = find_closest_distance(itv_aed, aed)
itv_aed.head()
# Out:
#     mission_id                         service_name  postalcode_permanence  \
# 0  20222490147  FB PDS SCHA [PASI Paul Brien] SIAMU                 1030.0
# 2  20222490155          HB UR BRUX Europe Elisabeth                 1180.0
# 3  20222490162        FB PDS BRUX [PASI CitÈ] SIAMU                 1000.0
# 4  20222490200  FB PDS ANDE [PASI Anderlecht] SIAMU                 1070.0
# 7  20222490246                   HB UR BRUX St Jean                 1000.0
#
#        cityname_permanence streetname_permanence  housenumber_permanence  \
# 0  Schaarbeek (Schaarbeek)    ChaussÈe de Haecht                     NaN
# 2            ukkel (ukkel)            de frÈlaan                     NaN
# 3        Brussel (Brussel)        Vesaliusstraat                     NaN
# 4               Anderlecht     Bergense Steenweg                     NaN
# 7        Brussel (Brussel)           Broekstraat                     NaN
#
#    latitude_permanence  longitude_permanence permanence_short_name  \
# 0             50.86948               4.38649             ABSCHA01A
# 2             50.80470               4.36763             ABBRUX09A
# 3             50.85097               4.36411             ABBRUX11A
# 4             50.83254               4.31199             ABANDE03A
# 7             50.85230               4.35988             UBBRUX02A
#
#   permanence_long_name  ... t7_Hour t7_Day t7_Month t7_DayName  \
# 0          AMB BRIEN 1  ...    16.0    6.0      9.0    Tuesday
# 2   AMB ST ELISABETH 9  ...    17.0    6.0      9.0    Tuesday
# 3           AMB CITE 2  ...    17.0    6.0      9.0    Tuesday
# 4            AMB AND 3  ...    18.0    6.0      9.0    Tuesday
# 7        SMUR STJEAN 2  ...    21.0    6.0      9.0    Tuesday
#
#                          province  intervention_time_(t1confirmed)  \
# 0  Brussels Hoofdstedelijk Gewest                              NaN
# 2        Provincie Vlaams-Brabant                              NaN
# 3  Brussels Hoofdstedelijk Gewest                              NaN
# 4  Brussels Hoofdstedelijk Gewest                              NaN
# 7  Brussels Hoofdstedelijk Gewest                              NaN
#
#   departure_time_(t1confirmed)  aed_distance  hospital_distance  \
# 0                          NaN      5.954143        1670.861212
# 2                          NaN    389.414213        4173.642942
# 3                          NaN     13.534626        1034.347073
# 4                          NaN     46.578200        3008.489539
# 7                          NaN    166.420606        2087.394053
#
#   new_aed_distance
# 0        93.500820
# 2        23.661984
# 3        29.654307
# 4        21.247651
# 7        69.738682
#
# [5 rows x 57 columns]

# %%
## Cvoverage after kmeans optimization

kmeans_covered = itv_aed.loc[(
    (itv_aed['new_aed_distance'] <= speed_running * golden_minutes / 2) |
    (itv_aed['hospital_distance'] <= speed_driving * golden_minutes))]

coverage = len(kmeans_covered) / len(itv_aed)
print('Coverage of AEDs and hospitals after KMeans optimization:', coverage)
# Out:
# Coverage of AEDs and hospitals after KMeans optimization: 0.9960600449154879

# %%
## Add province information to the new AED locations

import geopandas as gpd
from shapely import geometry as geo
from shapely.validation import explain_validity

geo_path = '/Users/lye/Downloads/MDA/Github-MDA2024/1_Data/Belgium.provinces.WGS84.geojson'
geo_be = gpd.read_file(geo_path)

# Check if the geometries are valid
for i in range(len(geo_be)):
    if not geo_be.loc[i, 'geometry'].is_valid:
        print(explain_validity(geo_be.loc[i, 'geometry']))
        geo_be.loc[i, 'geometry'] = geo_be.loc[i, 'geometry'].buffer(0)
        print(geo_be.loc[i, 'geometry'].is_valid)
# Out:
# Self-intersection[6.24760990547934 50.640636186645]
# True

# %%
def get_medical_province(df, geo_df):
    province = []
    missing_province = 0
    for i in range(len(df)):
        point = geo.Point(df.loc[i, 'new_lon'], df.loc[i, 'new_lat'])
        contained = geo_df.loc[geo_df['geometry'].contains(
            point)]['NameDUT'].values
        if contained.size > 0:
            province.append(contained[0])
        else:
            province.append(None)
            missing_province += 1

    df['new_province'] = province
    print(f'{missing_province} coordinates are not located in any province')

    return df


aed = get_medical_province(aed, geo_be)
aed['new_province'].value_counts()
# Out:
# 0 coordinates are not located in any province
# new_province
# Provincie Antwerpen               2438
# Provincie Oost-Vlaanderen         2183
# Provincie Henegouwen              1953
# Provincie Vlaams-Brabant          1916
# Provincie West-Vlaanderen         1660
# Provincie Luik                    1512
# Provincie Limburg                 1322
# Brussels Hoofdstedelijk Gewest     925
# Provincie Namen                    821
# Provincie Waals-Brabant            533
# Provincie Luxemburg                512
# Name: count, dtype: int64

# %%
aed.to_csv('/Users/lye/Downloads/MDA/Github-MDA2024/1_Data/CLEANED/aed_with_KmeansLocation.csv', index=False)
itv_aed.to_csv('/Users/lye/Downloads/MDA/Github-MDA2024/1_Data/CLEANED/intervention_aed_kmeans_distance.csv', index=False)

# %%
aed['province'].value_counts()
# Out:
# province
# Antwerpen            2355
# Bruxelles-brussel    2117
# Hainaut              1950
# Liège                1771
# Oost-vlaanderen      1664
# West-vlaanderen      1374
# Vlaams-brabant       1282
# Limburg               998
# Namur                 900
# Luxembourg            683
# Brabant wallon        681
# Name: count, dtype: int64
