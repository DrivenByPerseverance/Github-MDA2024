# %%
import pandas as pd
import numpy as np
import os

# %%
pwd
# Out:
# '/Users/lye/Downloads/MDA'

# %%
## Check the path of datafiles
path = "./data"
files = os.listdir(path)
files
# Out:
# ['mug_locations.parquet.gzip',
#  'interventions_bxl2.parquet.gzip',
#  'pit_locations.parquet.gzip',
#  'interventions_bxl.parquet.gzip',
#  'interventions1.parquet.gzip',
#  'cad9.parquet.gzip',
#  'aed_locations.parquet.gzip',
#  'interventions2.parquet.gzip',
#  'ambulance_locations.parquet.gzip',
#  'interventions3.parquet.gzip']

# %%
## Read datafiles as DataFrames

mug_loc = pd.read_parquet(path + '/' + files[0], engine='pyarrow')
pit_loc = pd.read_parquet(path + '/' + files[2], engine='pyarrow')
aed_loc = pd.read_parquet(path + '/' + files[6], engine='pyarrow')
ambu_loc = pd.read_parquet(path + '/' + files[-2], engine='pyarrow')

# %%
aed_loc.head()
# Out:
#      id  type                address  number  postal_code municipality  \
# 0  13.0  None    Blvd. Fr. Roosevelt    24.0       7060.0     SOIGNIES
# 1  70.0  None        Ch. De Wégimont    76.0       4630.0      Ayeneux
# 2  71.0  None  Place Saint - Lambert     NaN       4020.0        Liège
# 3  72.0  None          Rue du Doyard     NaN       4990.0     Lierneux
# 4  73.0  None     Fond Saint Servais     NaN       4000.0        Liège
#
#   province location public available hours
# 0  Hainaut     None      Y      None  None
# 1    Liège     None   None      None  None
# 2    Liège     None   None      None  None
# 3    Liège     None   None      None  None
# 4    Liège     None   None      None  None

# %%
aed_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15227 entries, 0 to 15226
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            15225 non-null  float64
#  1   type          5167 non-null   object
#  2   address       15225 non-null  object
#  3   number        13085 non-null  float64
#  4   postal_code   15193 non-null  float64
#  5   municipality  15142 non-null  object
#  6   province      15190 non-null  object
#  7   location      8423 non-null   object
#  8   public        8079 non-null   object
#  9   available     4290 non-null   object
#  10  hours         1077 non-null   object
# dtypes: float64(3), object(8)
# memory usage: 1.3+ MB

# %%
## Adjust the format of address variables 

aed_loc['address'] = aed_loc['address'].str.replace(r'\s*-\s*', '-', regex=True)
aed_loc['address'] = aed_loc['address'].str.capitalize()
aed_loc['municipality'] = aed_loc['municipality'].str.capitalize()
aed_loc['province'] = aed_loc['province'].str.capitalize()
aed_loc['postal_code'] = aed_loc['postal_code'].fillna('').astype(str).str[:-2]

# %%
## Concate the address to full address

aed_loc['full_address'] = aed_loc['address'] + ', ' + aed_loc['postal_code'] + ' ' + aed_loc['municipality'] + ', ' + aed_loc['province']

aed_loc.head()
# Out:
#      id  type              address  number postal_code municipality province  \
# 0  13.0  None  Blvd. fr. roosevelt    24.0        7060     Soignies  Hainaut
# 1  70.0  None      Ch. de wégimont    76.0        4630      Ayeneux    Liège
# 2  71.0  None  Place saint-lambert     NaN        4020        Liège    Liège
# 3  72.0  None        Rue du doyard     NaN        4990     Lierneux    Liège
# 4  73.0  None   Fond saint servais     NaN        4000        Liège    Liège
#
#   location public available hours                                 full_address
# 0     None      Y      None  None  Blvd. fr. roosevelt, 7060 Soignies, Hainaut
# 1     None   None      None  None         Ch. de wégimont, 4630 Ayeneux, Liège
# 2     None   None      None  None       Place saint-lambert, 4020 Liège, Liège
# 3     None   None      None  None          Rue du doyard, 4990 Lierneux, Liège
# 4     None   None      None  None        Fond saint servais, 4000 Liège, Liège

# %%
## Drop NA and duplicates

aed_loc.dropna(subset=['id', 'full_address'], inplace=True)
aed_loc.drop_duplicates(subset=['id', 'full_address'], inplace=True)

# %%
import googlemaps
import time

# %%
## generate latitude and longitude using GoogleMap API

def get_coordinate_from_gmap(df):

    gmaps = googlemaps.Client(key='Your_Key')
    
    i = 1
    id = list()
    lat = list()
    lon = list()
    address = list()
    
    for index, row in df.iterrows():
        id.append(i)
        full_address = row['full_address']
        address.append(full_address)
        
        try:
            geocode_result = gmaps.geocode(full_address)
            temp_lat = geocode_result[0]['geometry']['location']['lat']
            temp_lon = geocode_result[0]['geometry']['location']['lng']
            lat.append(temp_lat)
            lon.append(temp_lon)
            time.sleep(0.05)  #limit the retreiving speed
            
        except:
            print('Fail to get location data')
            lat.append(np.nan)
            lon.append(np.nan)

        i += 1
        if i % 500 == 0:
            print(f'{i} records retrieved')

    df_coordinates = pd.DataFrame(dict(id=id, full_address=address, lat=lat, lon=lon))

    return df_coordinates

# %%
aed_coordinates = get_coordinate_from_gmap(aed_loc)
# Out:
# 500 records retrieved
# 1000 records retrieved
# 1500 records retrieved
# 2000 records retrieved
# 2500 records retrieved
# 3000 records retrieved
# 3500 records retrieved
# 4000 records retrieved
# 4500 records retrieved
# 5000 records retrieved
# 5500 records retrieved
# 6000 records retrieved
# 6500 records retrieved
# 7000 records retrieved
# 7500 records retrieved
# 8000 records retrieved
# 8500 records retrieved
# 9000 records retrieved
# 9500 records retrieved
# 10000 records retrieved
# 10500 records retrieved
# 11000 records retrieved
# 11500 records retrieved
# 12000 records retrieved
# 12500 records retrieved
# 13000 records retrieved
# 13500 records retrieved
# 14000 records retrieved
# 14500 records retrieved
# 15000 records retrieved

# %%
aed_coordinates.head()
# Out:
#      id        lat       lon
# 0  13.0  50.576042  4.065740
# 1  70.0  50.607680  5.730187
# 2  71.0  50.645622  5.573620
# 3  72.0  50.287416  5.786325
# 4  73.0  50.646806  5.571031

# %%
## Merge coordinates to the original dataset
merged_aed_loc = pd.merge(aed_loc, aed_coordinates, on='full_address')
merged_aed_loc.head()
# Out:
#      id  type              address  number postal_code municipality province  \
# 0  13.0  None  Blvd. fr. roosevelt    24.0        7060     Soignies  Hainaut
# 1  70.0  None      Ch. de wégimont    76.0        4630      Ayeneux    Liège
# 2  71.0  None  Place saint-lambert     NaN        4020        Liège    Liège
# 3  72.0  None        Rue du doyard     NaN        4990     Lierneux    Liège
# 4  73.0  None   Fond saint servais     NaN        4000        Liège    Liège
#
#   location public available hours  \
# 0     None      Y      None  None
# 1     None   None      None  None
# 2     None   None      None  None
# 3     None   None      None  None
# 4     None   None      None  None
#
#                                   full_address        lat       lon
# 0  Blvd. fr. roosevelt, 7060 Soignies, Hainaut  50.576042  4.065740
# 1         Ch. de wégimont, 4630 Ayeneux, Liège  50.607680  5.730187
# 2       Place saint-lambert, 4020 Liège, Liège  50.645622  5.573620
# 3          Rue du doyard, 4990 Lierneux, Liège  50.287416  5.786325
# 4        Fond saint servais, 4000 Liège, Liège  50.646806  5.571031

# %%
merged_aed_loc.to_csv('./aed_location_latlon.csv', index=False) ## Save merged AED location to .csv file

# %%
pit_loc.head(10)
# Out:
#                                               unit  \
# 0                 100001: PIT Rumst, AZ Rivierland
# 1               102001: PIT Deinze, St Vincentius
# 2                          102101: PIT Stuivenberg
# 3                    110001: PIT Lier, Heilig Hart
# 4               113001: PIT HEILIG HART ZIEKENHUIS
# 5                              200001: PIT LOKEREN
# 6                            210001: PIT ASSE, OLV
# 7         301001: PIT ST Jan (Associatie St Lucas)
# 8  301001: PIT St Lucas Brugge (associatie St Jan)
# 9                         303001: PIT Blankenberge
#
#                                               campus  \
# 0  Ziekenhuis/Hôpital: 104 - AZ RIVIERENLAND --- ...
# 1  Ziekenhuis/Hôpital: 134 - AZ SINT-VINCENTIUS -...
# 2  Ziekenhuis/Hôpital: 009 - ZIEKENHUISNETWERK AN...
# 3  Ziekenhuis/Hôpital: 097 - HEILIG HART ZIEKENHU...
# 4  Ziekenhuis/Hôpital: 102 - HEILIG HART ZIEKENHU...
# 5  Ziekenhuis/Hôpital: 595 - VITAZ --- Campus/Sit...
# 6  Ziekenhuis/Hôpital: 126 - ONZE-LIEVE-VROUW ZIE...
# 7  Ziekenhuis/Hôpital: 049 - AZ SINT-JAN BRUGGE -...
# 8  Ziekenhuis/Hôpital: 140 - AZ SINT-LUCAS --- Ca...
# 9  Ziekenhuis/Hôpital: 392 - AZ ZENO --- Campus/S...
#
#                               province              region    unit_id  \
# 0                     Antwerpen/Anvers  Vlaanderen/Flandre  PARUMS01A
# 1    Oost-Vlaanderen/Flandre orientale  Vlaanderen/Flandre  PODEIN01A
# 2                     Antwerpen/Anvers  Vlaanderen/Flandre  PAANTW01A
# 3                     Antwerpen/Anvers  Vlaanderen/Flandre  PALIER01A
# 4                     Antwerpen/Anvers  Vlaanderen/Flandre  PAMOL_01A
# 5    Oost-Vlaanderen/Flandre orientale  Vlaanderen/Flandre  POLOKE01A
# 6       Vlaams Brabant/Brabant flamand  Vlaanderen/Flandre  PVASSE01A
# 7  West-Vlaanderen/Flandre occidentale  Vlaanderen/Flandre  PWBRUG01A
# 8  West-Vlaanderen/Flandre occidentale  Vlaanderen/Flandre  PWBRUG02A
# 9  West-Vlaanderen/Flandre occidentale  Vlaanderen/Flandre  PWBLAN01A
#
#    ambucode  ambusitecode                                               link
# 0       191         19101                                               None
# 1       413         41301                                               None
# 2       117         11704                                               None
# 3       171         17101                                               None
# 4       190         19001                                               None
# 5       440         44001                                               None
# 6       480         48001                                               None
# 7       391         39102  PIT 301001 gelinkt aan de ziekenhuizen/lié aux...
# 8       391         39101  PIT 301001 gelinkt aan de ziekenhuizen/lié aux...
# 9       374         37401                                               None

# %%
mug_loc.head(10)
# Out:
#    hospital_id  mug_id  campus_id                      name_hospital  \
# 0            9  102000       6230  ZIEKENHUISNETWERK ANTWERPEN (ZNA)
# 1           99  102000       2020                  GZA- ZIEKENHUIZEN
# 2          682  102000       1210                          AZ MONICA
# 3            9  103000       2000  ZIEKENHUISNETWERK ANTWERPEN (ZNA)
# 4           99  103000       1290                  GZA- ZIEKENHUIZEN
# 5            9  104000       3360  ZIEKENHUISNETWERK ANTWERPEN (ZNA)
# 6          710  104000       3450                           AZ KLINA
# 7          300  105000       4220  UNIVERSITAIR ZIEKENHUIS ANTWERPEN
# 8          308  106000       1250                       AZ HERENTALS
# 9           63  107000       1280                        AZ TURNHOUT
#
#         name_campus           address_campus  postal_code municipality region  \
# 0         ZNA CADIX         KEMPENSTRAAT 100         2030    ANTWERPEN      V
# 1   SINT-VINCENTIUS  ST.-VINCENTIUSSTRAAT 20         2018    ANTWERPEN      V
# 2            DEURNE     FLORENT PAUWELSLEI 1         2100       DEURNE      V
# 3    ZNA MIDDELHEIM            LINDENDREEF 1         2020    ANTWERPEN      V
# 4  SINT- AUGUSTINUS        OOSTERVELDLAAN 24         2610      WILRIJK      V
# 5   ZNA JAN PALFIJN      LANGE BREMSTRAAT 70         2170      MERKSEM      V
# 6              None        AUGUSTIJNSLEI 100         2930   BRASSCHAAT      V
# 7              None     DRIE EIKENSTRAAT 655         2650       EDEGEM      V
# 8              None             NEDERRIJ 133         2200    HERENTALS      V
# 9    SINT-ELISABETH         RUBENSSTRAAT 166         2300     TURNHOUT      V
#
#     province
# 0  Antwerpen
# 1  Antwerpen
# 2  Antwerpen
# 3  Antwerpen
# 4  Antwerpen
# 5  Antwerpen
# 6  Antwerpen
# 7  Antwerpen
# 8  Antwerpen
# 9  Antwerpen

# %%
ambu_loc.head(10)
# Out:
#                                      base  \
# 0             BA ANTW [Borgerhout] AMBUCE
# 1                BA ANTW [Hoboken] AMBUCE
# 2  BA ANTW [Hof Ter Schelde] AC Antwerpen
# 3                BA ANTW [Kaai 606] SIHWA
# 4   BA ANTW [Sint Elisabeth] AC Antwerpen
# 5               BA AREN Gemeente Arendonk
# 6                       BA BEER AD BEERSE
# 7                      BA BERL Rode Kruis
# 8                  BA ESSE Gemeente Essen
# 9                   BA HERS Hulshoutse AD
#
#                                     medical_resource   province  \
# 0                   ZW ANTWERPEN 7 (Team: AAANTW07A)  Antwerpen
# 1                   ZW ANTWERPEN 9 (Team: AAANTW09A)  Antwerpen
# 2                   ZW ANTWERPEN 3 (Team: AAANTW03A)  Antwerpen
# 3  ZW ANTWERPEN HAVEN 1 (Team: AAAPOR01A)_x000D_Z...  Antwerpen
# 4                   ZW ANTWERPEN 2 (Team: AAANTW02A)  Antwerpen
# 5                    ZW ARENDONK 1 (Team: AAAREN01A)  Antwerpen
# 6                      ZW BEERSE 1 (Team: AABEER01A)  Antwerpen
# 7                     ZW BERLAAR 1 (Team: AABERL01A)  Antwerpen
# 8                       ZW ESSEN 1 (Team: AAESSE01A)  Antwerpen
# 9                    ZW HULSHOUT 1 (Team: AAHERS01A)  Antwerpen
#
#           region                         departure_location  \
# 0  Vlaams Gewest           Gijselstraat 150 2140 BORGERHOUT
# 1  Vlaams Gewest         Antwerpsesteenweg 242 2660 HOBOKEN
# 2  Vlaams Gewest      August Vermeylenlaan 6 2050 ANTWERPEN
# 3  Vlaams Gewest  Antwerpsebaan 4 (Kaai 606) 2040 ANTWERPEN
# 4  Vlaams Gewest            Leopoldstraat 26 2000 ANTWERPEN
# 5  Vlaams Gewest                Hovestraat 46 2370 ARENDONK
# 6  Vlaams Gewest                  IJzerstraat 3 2340 BEERSE
# 7  Vlaams Gewest                Zomerstraat 26 2590 BERLAAR
# 8  Vlaams Gewest                  Heuvelplein 23 2910 ESSEN
# 9  Vlaams Gewest              Harmoniestraat 9A 2230 RAMSEL
#
#    departure_location_number   latitude  longitude occasional_permanence
# 0                       3811  51.215516   4.443788                     N
# 1                       3812  51.178831   4.361948                     N
# 2                      10902  51.232810   4.377237                     N
# 3                      12902  51.315516   4.321506                     N
# 4                      10901  51.213623   4.405718                     N
# 5                      12101  51.319819   5.089912                     N
# 6                      14701  51.320983   4.856656                     N
# 7                       3511  51.114055   4.647246                     N
# 8                      16403  51.464673   4.472551                     N
# 9                      16803  51.043064   4.815907                     N

# %%
mug_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   hospital_id     94 non-null     int64
#  1   mug_id          94 non-null     int64
#  2   campus_id       94 non-null     int64
#  3   name_hospital   94 non-null     object
#  4   name_campus     59 non-null     object
#  5   address_campus  94 non-null     object
#  6   postal_code     94 non-null     int64
#  7   municipality    94 non-null     object
#  8   region          94 non-null     object
#  9   province        94 non-null     object
# dtypes: int64(4), object(6)
# memory usage: 7.5+ KB

# %%
## Adjust the format of address variables 

mug_loc['address_campus'] = mug_loc['address_campus'].str.capitalize()
mug_loc['municipality'] = mug_loc['municipality'].str.capitalize()
mug_loc['province'] = mug_loc['province'].str.capitalize()
mug_loc['postal_code'] = mug_loc['postal_code'].fillna('').astype(str)
mug_loc['name_hospital'] = mug_loc['name_hospital'].str.title()
mug_loc['name_hospital'] = mug_loc['name_hospital'].str.replace(r'\s*-\s*', '-', regex=True)

# %%
## Concate address to full address
mug_loc['full_address'] = mug_loc['address_campus'] + ', ' + mug_loc['postal_code'] + ' ' + mug_loc['municipality'] + ', ' + mug_loc['province']

mug_loc.head()
# Out:
#    hospital_id  mug_id  campus_id                      name_hospital  \
# 0            9  102000       6230  Ziekenhuisnetwerk Antwerpen (Zna)
# 1           99  102000       2020                   Gza-Ziekenhuizen
# 2          682  102000       1210                          Az Monica
# 3            9  103000       2000  Ziekenhuisnetwerk Antwerpen (Zna)
# 4           99  103000       1290                   Gza-Ziekenhuizen
#
#         name_campus           address_campus postal_code municipality region  \
# 0         ZNA CADIX         Kempenstraat 100        2030    Antwerpen      V
# 1   SINT-VINCENTIUS  St.-vincentiusstraat 20        2018    Antwerpen      V
# 2            DEURNE     Florent pauwelslei 1        2100       Deurne      V
# 3    ZNA MIDDELHEIM            Lindendreef 1        2020    Antwerpen      V
# 4  SINT- AUGUSTINUS        Oosterveldlaan 24        2610      Wilrijk      V
#
#     province                                       full_address
# 0  Antwerpen        Kempenstraat 100, 2030 Antwerpen, Antwerpen
# 1  Antwerpen  St.-vincentiusstraat 20, 2018 Antwerpen, Antwe...
# 2  Antwerpen       Florent pauwelslei 1, 2100 Deurne, Antwerpen
# 3  Antwerpen           Lindendreef 1, 2020 Antwerpen, Antwerpen
# 4  Antwerpen         Oosterveldlaan 24, 2610 Wilrijk, Antwerpen

# %%
## Drop NA and duplicates
mug_loc.dropna(subset=['full_address'], inplace=True)
mug_loc.drop_duplicates(subset=['full_address'], inplace=True)

# %%
## Get latitude and longitude of mug
mug_coordinates = get_coordinate_from_gmap(mug_loc)

# %%
mug_coordinates.head()
# Out:
#    id                                       full_address        lat       lon
# 0   1        Kempenstraat 100, 2030 Antwerpen, Antwerpen  51.231380  4.415252
# 1   2  St.-vincentiusstraat 20, 2018 Antwerpen, Antwe...  51.206009  4.412680
# 2   3       Florent pauwelslei 1, 2100 Deurne, Antwerpen  51.206367  4.470202
# 3   4           Lindendreef 1, 2020 Antwerpen, Antwerpen  51.183318  4.421585
# 4   5         Oosterveldlaan 24, 2610 Wilrijk, Antwerpen  51.175223  4.416653

# %%
## Merge the generated coordinates to original dataset
merged_mug_loc = pd.merge(mug_loc, mug_coordinates, on='full_address')
merged_mug_loc.head()
# Out:
#    hospital_id  mug_id  campus_id                      name_hospital  \
# 0            9  102000       6230  Ziekenhuisnetwerk Antwerpen (Zna)
# 1           99  102000       2020                   Gza-Ziekenhuizen
# 2          682  102000       1210                          Az Monica
# 3            9  103000       2000  Ziekenhuisnetwerk Antwerpen (Zna)
# 4           99  103000       1290                   Gza-Ziekenhuizen
#
#         name_campus           address_campus postal_code municipality region  \
# 0         ZNA CADIX         Kempenstraat 100        2030    Antwerpen      V
# 1   SINT-VINCENTIUS  St.-vincentiusstraat 20        2018    Antwerpen      V
# 2            DEURNE     Florent pauwelslei 1        2100       Deurne      V
# 3    ZNA MIDDELHEIM            Lindendreef 1        2020    Antwerpen      V
# 4  SINT- AUGUSTINUS        Oosterveldlaan 24        2610      Wilrijk      V
#
#     province                                       full_address  id  \
# 0  Antwerpen        Kempenstraat 100, 2030 Antwerpen, Antwerpen   1
# 1  Antwerpen  St.-vincentiusstraat 20, 2018 Antwerpen, Antwe...   2
# 2  Antwerpen       Florent pauwelslei 1, 2100 Deurne, Antwerpen   3
# 3  Antwerpen           Lindendreef 1, 2020 Antwerpen, Antwerpen   4
# 4  Antwerpen         Oosterveldlaan 24, 2610 Wilrijk, Antwerpen   5
#
#          lat       lon
# 0  51.231380  4.415252
# 1  51.206009  4.412680
# 2  51.206367  4.470202
# 3  51.183318  4.421585
# 4  51.175223  4.416653

# %%
merged_mug_loc.to_csv('./mug_location_latlon.csv', index=False) ## Save to .csv file

# %%
pit_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          24 non-null     object
#  1   campus        24 non-null     object
#  2   province      21 non-null     object
#  3   region        24 non-null     object
#  4   unit_id       24 non-null     object
#  5   ambucode      24 non-null     int64
#  6   ambusitecode  24 non-null     int64
#  7   link          2 non-null      object
# dtypes: int64(2), object(6)
# memory usage: 1.6+ KB

# %%
pit_loc['campus'].tolist()
# Out:
# ['Ziekenhuis/Hôpital: 104 - AZ RIVIERENLAND --- Campus/Site: 1270 - RUMST',
#  'Ziekenhuis/Hôpital: 134 - AZ SINT-VINCENTIUS --- Campus/Site: 1830 - AZ SINT-VINCENTIUS DEINZE',
#  'Ziekenhuis/Hôpital: 009 - ZIEKENHUISNETWERK ANTWERPEN (ZNA) --- Campus/Site: 1180 - ZNA STUIVENBERG',
#  'Ziekenhuis/Hôpital: 097 - HEILIG HART ZIEKENHUIS --- Campus/Site: 1260 - HEILIG HART',
#  'Ziekenhuis/Hôpital: 102 - HEILIG HART ZIEKENHUIS --- Campus/Site: 2080 - HEILIG HART ZIEKENHUIS MOL',
#  'Ziekenhuis/Hôpital: 595 - VITAZ --- Campus/Site: 1650 - VITAZ CAMPUS LOKEREN',
#  'Ziekenhuis/Hôpital: 126 - ONZE-LIEVE-VROUW ZIEKENHUIS --- Campus/Site: 1300 - OLV ZIEKENHUIS ASSE',
#  'Ziekenhuis/Hôpital: 049 - AZ SINT-JAN BRUGGE - OOSTENDE --- Campus/Site: 1010 - AZ SINT-JAN BRUGGE',
#  'Ziekenhuis/Hôpital: 140 - AZ SINT-LUCAS --- Campus/Site: 1000 - SINT- LUCAS',
#  'Ziekenhuis/Hôpital: 392 - AZ ZENO --- Campus/Site: 1040 - AZ ZENO BLANKENBERGE',
#  'Ziekenhuis/Hôpital: 371 - ZIEKENHUIS OOST-LIMBURG --- Campus/Site: 3560 - SINT-JAN GENK',
#  'Ziekenhuis/Hôpital: 322 - UZ LEUVEN --- Campus/Site: 4230 - GASTHUISBERG',
#  'Ziekenhuis/Hôpital: 087 - HOPITAUX IRIS SUD --- Campus/Site: 1560 - ETTERBEEK - IXELLES',
#  'Ziekenhuis/Hôpital: 076 - CHU SAINT-PIERRE --- Campus/Site: 1520 - PORTE DE HAL',
#  'Ziekenhuis/Hôpital: 143 - UNIVERSITAIR ZIEKENHUIS BRUSSEL --- Campus/Site: 4200 - U.Z. BRUSSEL',
#  'Ziekenhuis/Hôpital: 010 - GRAND HOPITAL DE CHARLEROI --- Campus/Site: 3170 - SAINT- JOSEPH',
#  'Ziekenhuis/Hôpital: 254 - C.H.U. AMBROISE PARE --- Campus/Site: 2730 - AMBROISE PARE',
#  'Ziekenhuis/Hôpital: 006 - CHR SAMBRE ET MEUSE (SITE MEUSE) --- Campus/Site: 3300 - CHRSM - SITE MEUSE',
#  'Ziekenhuis/Hôpital: 023 - CLINIQUE ANDRE RENARD --- Campus/Site: 2860 - ANDRE RENARD',
#  'Ziekenhuis/Hôpital: 412 - HOPITAL DE LA CITADELLE --- Campus/Site: 3410 - CITADELLE',
#  'Ziekenhuis/Hôpital: 020 - CHR VERVIERS - EAST BELGIUM --- Campus/Site: 3010 - LA TOURELLE',
#  'Ziekenhuis/Hôpital: 004 - CENTRE HOSPITALIER REINE ASTRID --- Campus/Site: 2950 - REINE ASTRID',
#  'Ziekenhuis/Hôpital: 246 - VIVALIA - HOPITAL ARLON ET VIRTON --- Campus/Site: 3700 - HOPITAL DE VIRTON',
#  'Ziekenhuis/Hôpital: 168 - VIVALIA - CENTRE HOSPITALIER CENTRE ARDENNE --- Campus/Site: 3240 - HOPITAL DE LIBRAMONT']

# %%
gmaps = googlemaps.Client(key='Your_key')

len(gmaps.geocode('Az Rivierenland'))
# Out:
# 0

# %%
## Extract hospital name and campus name from 'campus' variable using regex
pattern = r'Hôpital: \d+ - (.*?) --- Campus/Site: \d+ - (.*)'

pit_loc[['hospital_name', 'campus_name']] = pit_loc['campus'].str.extract(pattern)
pit_loc['hospital_name'] = pit_loc['hospital_name'].str.title()
pit_loc['campus_name'] = pit_loc['campus_name'].str.title()

# %%
pit_loc.loc[0, 'hospital_name'] = pit_loc.loc[0, 'hospital_name'] + ' ' + pit_loc.loc[0, 'campus_name']

# %%
pit_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   unit           24 non-null     object
#  1   campus         24 non-null     object
#  2   province       21 non-null     object
#  3   region         24 non-null     object
#  4   unit_id        24 non-null     object
#  5   ambucode       24 non-null     int64
#  6   ambusitecode   24 non-null     int64
#  7   link           2 non-null      object
#  8   hospital_name  24 non-null     object
#  9   campus_name    24 non-null     object
# dtypes: int64(2), object(8)
# memory usage: 2.0+ KB

# %%
## Get coordinates of PIT

def get_pit_from_gmap(df):

    gmaps = googlemaps.Client(key='AIzaSyBosTmYB58hqnojOY3zh-rNB5g8lzdNyRc')
    
    i = 1
    lat = list()
    lon = list()
    hospital_name = list()
    campus_name = list()
    
    for index, row in df.iterrows():
        hospital_name.append(row['hospital_name'])
        campus_name.append(row['campus_name'])
        try:
            geocode_result = gmaps.geocode(row['hospital_name'])
            if len(geocode_result)==0:
                geocode_result = gmaps.geocode(row['campus_name'])
            else:
                geocode_result = gmaps.geocode(row['hospital_name'])
                
            temp_lat = geocode_result[0]['geometry']['location']['lat']
            temp_lon = geocode_result[0]['geometry']['location']['lng']
            lat.append(temp_lat)
            lon.append(temp_lon)
            time.sleep(0.05)  #limit the retreiving speed
            
        except:
            print('Fail to get location data')
            lat.append(np.nan)
            lon.append(np.nan)

        print(f'{i} records retrieved')
        i += 1

    df_coordinates = pd.DataFrame(dict(hospital_name=hospital_name, campus_name=campus_name, lat=lat, lon=lon))

    return df_coordinates

# %%
pit_coordinates = get_pit_from_gmap(pit_loc)
# Out:
# 1 records retrieved
# 2 records retrieved
# 3 records retrieved
# Fail to get location data
# 4 records retrieved
# 5 records retrieved
# 6 records retrieved
# 7 records retrieved
# 8 records retrieved
# 9 records retrieved
# 10 records retrieved
# 11 records retrieved
# 12 records retrieved
# 13 records retrieved
# 14 records retrieved
# 15 records retrieved
# 16 records retrieved
# 17 records retrieved
# 18 records retrieved
# 19 records retrieved
# 20 records retrieved
# 21 records retrieved
# 22 records retrieved
# 23 records retrieved
# 24 records retrieved

# %%
pit_coordinates
# Out:
#                                   hospital_name                 campus_name  \
# 0                         Az Rivierenland Rumst                       Rumst
# 1                            Az Sint-Vincentius   Az Sint-Vincentius Deinze
# 2             Ziekenhuisnetwerk Antwerpen (Zna)             Zna Stuivenberg
# 3                        Heilig Hart Ziekenhuis                 Heilig Hart
# 4                        Heilig Hart Ziekenhuis  Heilig Hart Ziekenhuis Mol
# 5                                         Vitaz        Vitaz Campus Lokeren
# 6                   Onze-Lieve-Vrouw Ziekenhuis         Olv Ziekenhuis Asse
# 7                 Az Sint-Jan Brugge - Oostende          Az Sint-Jan Brugge
# 8                                 Az Sint-Lucas                 Sint- Lucas
# 9                                       Az Zeno        Az Zeno Blankenberge
# 10                      Ziekenhuis Oost-Limburg               Sint-Jan Genk
# 11                                    Uz Leuven                Gasthuisberg
# 12                            Hopitaux Iris Sud         Etterbeek - Ixelles
# 13                             Chu Saint-Pierre                Porte De Hal
# 14              Universitair Ziekenhuis Brussel                U.Z. Brussel
# 15                   Grand Hopital De Charleroi               Saint- Joseph
# 16                         C.H.U. Ambroise Pare               Ambroise Pare
# 17             Chr Sambre Et Meuse (Site Meuse)          Chrsm - Site Meuse
# 18                        Clinique Andre Renard                Andre Renard
# 19                      Hopital De La Citadelle                   Citadelle
# 20                  Chr Verviers - East Belgium                 La Tourelle
# 21              Centre Hospitalier Reine Astrid                Reine Astrid
# 22            Vivalia - Hopital Arlon Et Virton           Hopital De Virton
# 23  Vivalia - Centre Hospitalier Centre Ardenne        Hopital De Libramont
#
#           lat        lon
# 0   51.106484   4.371312
# 1   50.986082   3.528019
# 2   51.181775   4.421241
# 3         NaN        NaN
# 4   51.187084   5.114250
# 5   48.971165  20.954643
# 6   50.943134   4.055417
# 7   51.220115   3.193459
# 8   51.185125   3.249138
# 9   51.327595   3.291226
# 10  50.957077   5.518037
# 11  50.879055   4.671738
# 12  50.834935   4.389242
# 13  50.834339   4.347137
# 14  50.887814   4.308604
# 15  50.417915   4.453919
# 16  50.457563   3.963070
# 17  49.082432   5.282400
# 18  50.674779   5.633445
# 19  50.651975   5.576939
# 20  50.582506   5.859816
# 21  50.426116   6.023917
# 22  49.567263   5.531373
# 23  49.925376   5.380329

# %%
## Merge coordinates to original data
merged_pit_loc = pd.merge(pit_loc, pit_coordinates, on=['hospital_name', 'campus_name'])
merged_pit_loc
# Out:
#                                                unit  \
# 0                  100001: PIT Rumst, AZ Rivierland
# 1                102001: PIT Deinze, St Vincentius
# 2                           102101: PIT Stuivenberg
# 3                     110001: PIT Lier, Heilig Hart
# 4                113001: PIT HEILIG HART ZIEKENHUIS
# 5                               200001: PIT LOKEREN
# 6                             210001: PIT ASSE, OLV
# 7          301001: PIT ST Jan (Associatie St Lucas)
# 8   301001: PIT St Lucas Brugge (associatie St Jan)
# 9                          303001: PIT Blankenberge
# 10                        404001: PIT Genk, St Jan
# 11                501001: PIT Leuven, Gasthuisberg
# 12                   520001: PIT Ixelles, Iris Sud
# 13                  523001: PIT St Pierre Bruxelles
# 14                           526001: PIT UZ BRUSSEL
# 15                                600001: PIT GILLY
# 16                                 601001: PIT MONS
# 17                            701001: PIT CHR NAMUR
# 18                              800001: PIT HERSTAL
# 19                            801001: PIT CITADELLE
# 20                             808001: PIT VERVIERS
# 21                              809001: PIT MALMEDY
# 22                               902001: PIT VIRTON
# 23                            903001: PIT LIBRAMONT
#
#                                                campus  \
# 0   Ziekenhuis/Hôpital: 104 - AZ RIVIERENLAND --- ...
# 1   Ziekenhuis/Hôpital: 134 - AZ SINT-VINCENTIUS -...
# 2   Ziekenhuis/Hôpital: 009 - ZIEKENHUISNETWERK AN...
# 3   Ziekenhuis/Hôpital: 097 - HEILIG HART ZIEKENHU...
# 4   Ziekenhuis/Hôpital: 102 - HEILIG HART ZIEKENHU...
# 5   Ziekenhuis/Hôpital: 595 - VITAZ --- Campus/Sit...
# 6   Ziekenhuis/Hôpital: 126 - ONZE-LIEVE-VROUW ZIE...
# 7   Ziekenhuis/Hôpital: 049 - AZ SINT-JAN BRUGGE -...
# 8   Ziekenhuis/Hôpital: 140 - AZ SINT-LUCAS --- Ca...
# 9   Ziekenhuis/Hôpital: 392 - AZ ZENO --- Campus/S...
# 10  Ziekenhuis/Hôpital: 371 - ZIEKENHUIS OOST-LIMB...
# 11  Ziekenhuis/Hôpital: 322 - UZ LEUVEN --- Campus...
# 12  Ziekenhuis/Hôpital: 087 - HOPITAUX IRIS SUD --...
# 13  Ziekenhuis/Hôpital: 076 - CHU SAINT-PIERRE ---...
# 14  Ziekenhuis/Hôpital: 143 - UNIVERSITAIR ZIEKENH...
# 15  Ziekenhuis/Hôpital: 010 - GRAND HOPITAL DE CHA...
# 16  Ziekenhuis/Hôpital: 254 - C.H.U. AMBROISE PARE...
# 17  Ziekenhuis/Hôpital: 006 - CHR SAMBRE ET MEUSE ...
# 18  Ziekenhuis/Hôpital: 023 - CLINIQUE ANDRE RENAR...
# 19  Ziekenhuis/Hôpital: 412 - HOPITAL DE LA CITADE...
# 20  Ziekenhuis/Hôpital: 020 - CHR VERVIERS - EAST ...
# 21  Ziekenhuis/Hôpital: 004 - CENTRE HOSPITALIER R...
# 22  Ziekenhuis/Hôpital: 246 - VIVALIA - HOPITAL AR...
# 23  Ziekenhuis/Hôpital: 168 - VIVALIA - CENTRE HOS...
#
#                                province  \
# 0                      Antwerpen/Anvers
# 1     Oost-Vlaanderen/Flandre orientale
# 2                      Antwerpen/Anvers
# 3                      Antwerpen/Anvers
# 4                      Antwerpen/Anvers
# 5     Oost-Vlaanderen/Flandre orientale
# 6        Vlaams Brabant/Brabant flamand
# 7   West-Vlaanderen/Flandre occidentale
# 8   West-Vlaanderen/Flandre occidentale
# 9   West-Vlaanderen/Flandre occidentale
# 10                     Limburg/Limbourg
# 11       Vlaams Brabant/Brabant flamand
# 12                                 None
# 13                                 None
# 14                                 None
# 15                   Henegouwen/Hainaut
# 16                   Henegouwen/Hainaut
# 17                          Namen/Namur
# 18                           Luik/Liège
# 19                           Luik/Liège
# 20                           Luik/Liège
# 21                           Luik/Liège
# 22                 Luxemburg/Luxembourg
# 23                 Luxemburg/Luxembourg
#
#                                                region    unit_id  ambucode  \
# 0                                  Vlaanderen/Flandre  PARUMS01A       191
# 1                                  Vlaanderen/Flandre  PODEIN01A       413
# 2                                  Vlaanderen/Flandre  PAANTW01A       117
# 3                                  Vlaanderen/Flandre  PALIER01A       171
# 4                                  Vlaanderen/Flandre  PAMOL_01A       190
# 5                                  Vlaanderen/Flandre  POLOKE01A       440
# 6                                  Vlaanderen/Flandre  PVASSE01A       480
# 7                                  Vlaanderen/Flandre  PWBRUG01A       391
# 8                                  Vlaanderen/Flandre  PWBRUG02A       391
# 9                                  Vlaanderen/Flandre  PWBLAN01A       374
# 10                                 Vlaanderen/Flandre  PLGENK01A       776
# 11                                 Vlaanderen/Flandre  PVLEUV01A       288
# 12  Brussels Hoofdstedelijk Gewest\nRégion de Brux...  PBIXEL01A       290
# 13  Brussels Hoofdstedelijk Gewest\nRégion de Brux...  PBBRUX01A       280
# 14  Brussels Hoofdstedelijk Gewest\nRégion de Brux...  PBJETT01A       270
# 15                                  Wallonië/Wallonie  PHCHAR01A       573
# 16                                  Wallonië/Wallonie  PHMONS01A       576
# 17                                  Wallonië/Wallonie  PNNAMU01A       971
# 18                                  Wallonië/Wallonie  PGHERS01A       636
# 19                                  Wallonië/Wallonie  PGLIEG01A       672
# 20                                  Wallonië/Wallonie  PGVERV01A       674
# 21                                  Wallonië/Wallonie  PGMALM01A       637
# 22                                  Wallonië/Wallonie  PXVIRT01A       870
# 23                                  Wallonië/Wallonie  PXBOUI01A       870
#
#     ambusitecode                                               link  \
# 0          19101                                               None
# 1          41301                                               None
# 2          11704                                               None
# 3          17101                                               None
# 4          19001                                               None
# 5          44001                                               None
# 6          48001                                               None
# 7          39102  PIT 301001 gelinkt aan de ziekenhuizen/lié aux...
# 8          39101  PIT 301001 gelinkt aan de ziekenhuizen/lié aux...
# 9          37401                                               None
# 10         77601                                               None
# 11         28801                                               None
# 12         29001                                               None
# 13         28001                                               None
# 14         27001                                               None
# 15         57301                                               None
# 16         57601                                               None
# 17         97101                                               None
# 18         63601                                               None
# 19         67201                                               None
# 20         67401                                               None
# 21         63701                                               None
# 22         87006                                               None
# 23         87005                                               None
#
#                                   hospital_name                 campus_name  \
# 0                         Az Rivierenland Rumst                       Rumst
# 1                            Az Sint-Vincentius   Az Sint-Vincentius Deinze
# 2             Ziekenhuisnetwerk Antwerpen (Zna)             Zna Stuivenberg
# 3                        Heilig Hart Ziekenhuis                 Heilig Hart
# 4                        Heilig Hart Ziekenhuis  Heilig Hart Ziekenhuis Mol
# 5                                         Vitaz        Vitaz Campus Lokeren
# 6                   Onze-Lieve-Vrouw Ziekenhuis         Olv Ziekenhuis Asse
# 7                 Az Sint-Jan Brugge - Oostende          Az Sint-Jan Brugge
# 8                                 Az Sint-Lucas                 Sint- Lucas
# 9                                       Az Zeno        Az Zeno Blankenberge
# 10                      Ziekenhuis Oost-Limburg               Sint-Jan Genk
# 11                                    Uz Leuven                Gasthuisberg
# 12                            Hopitaux Iris Sud         Etterbeek - Ixelles
# 13                             Chu Saint-Pierre                Porte De Hal
# 14              Universitair Ziekenhuis Brussel                U.Z. Brussel
# 15                   Grand Hopital De Charleroi               Saint- Joseph
# 16                         C.H.U. Ambroise Pare               Ambroise Pare
# 17             Chr Sambre Et Meuse (Site Meuse)          Chrsm - Site Meuse
# 18                        Clinique Andre Renard                Andre Renard
# 19                      Hopital De La Citadelle                   Citadelle
# 20                  Chr Verviers - East Belgium                 La Tourelle
# 21              Centre Hospitalier Reine Astrid                Reine Astrid
# 22            Vivalia - Hopital Arlon Et Virton           Hopital De Virton
# 23  Vivalia - Centre Hospitalier Centre Ardenne        Hopital De Libramont
#
#           lat        lon
# 0   51.106484   4.371312
# 1   50.986082   3.528019
# 2   51.181775   4.421241
# 3         NaN        NaN
# 4   51.187084   5.114250
# 5   48.971165  20.954643
# 6   50.943134   4.055417
# 7   51.220115   3.193459
# 8   51.185125   3.249138
# 9   51.327595   3.291226
# 10  50.957077   5.518037
# 11  50.879055   4.671738
# 12  50.834935   4.389242
# 13  50.834339   4.347137
# 14  50.887814   4.308604
# 15  50.417915   4.453919
# 16  50.457563   3.963070
# 17  49.082432   5.282400
# 18  50.674779   5.633445
# 19  50.651975   5.576939
# 20  50.582506   5.859816
# 21  50.426116   6.023917
# 22  49.567263   5.531373
# 23  49.925376   5.380329

# %%
merged_pit_loc.to_csv('./pit_location_latlon.csv', index=False) ## Save to file
